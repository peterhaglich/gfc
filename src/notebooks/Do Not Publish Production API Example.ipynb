# %% [markdown]
# # Using Python to Access the Geopolitical Forecasting Challenge 2 API
#
#
# ## Introduction
#
# Participation in Geopolitical Forecasting (GF) Challenge 2 is conducted through an API provided by Cultivate Labs. This notebook briefly demonstrates some ways to interact with the API through Python. These examples assume that you are familiar with Python 2 or 3, and have installed the [Requests](http://docs.python-requests.org/en/master/) library (which is included in distributions such as Anaconda). (NOTE: You may use these examples as part of your Challenge solution, but it is important to note that this code is meant primarily as a reference, and should not be assumed to be bug-free, or particularly efficient. We make no guarantees or warranties that this code will correctly retrieve or submit data to the API -- you are responsible for verifying that your forecasts are submitted correctly).
#
# Prior to participating in GF Challenge 2, you must register at [HeroX](https://www.herox.com/IARPAGFChallenge2), and then register on the Cultivate platform using the URLs provided. Upon registering on the Cultivate platform, you will be able to generate an API key for the staging (test) instance, and production (competition) instance of the API. This API key is unique to you, and you should ensure that it is not shared with others.  This API key is used to identify and authenticate your requests and submissions to the API.  (*Note that API keys from the first GF Challenge have been deactivated; you will need a new key to participate in GF Challenge 2*.)
#
# You will find complete [API documentation on the Cultivate Labs site](https://cultivate-hfc.github.io/gfc-api-docs/) once you receive your API key. This notebook does not provide an exhaustive overview of the entire API. Instead, it is designed to highlight some key considerations for implementing a GF Challenge 2 API client. It is not a substitute for a thorough understanding of the API documentation. This document describes some concepts related to the challenge, however, it is not an authoritative source of challenge rules. You are responsible for reviewing and understanding the official GF Challenge 2 Rules document available on the HeroX site.
#
# All code in this document is provided using the [CC0 1.0 Universal (CC0 1.0) Public Domain Dedication](https://creativecommons.org/publicdomain/zero/1.0/).
#
# ## General Details
#
# There are two separate but similar APIs for GF Challenge 2 on the Cultivate Labs platform.  The **Staging** platform (URL https://api.gfc-staging.com) is provided for Solvers to get familiar with the procedures for accessing the data and submitting forecasts in a practice mode.  The **Production** platform (URL https://api.iarpagfchallenge.com) is the platform for the competition.  The two platforms use separate API keys.  It is recommended that you use the Staging platform as you work through the code examples in this notebook.
#
# ### Using your API Key
#
# All calls to the API must include your API key in the request headers in the following form:
#
# `headers['Authorization'] = 'Bearer ' + secret_token`
#
# So, one can submit a GET request to the API this way:

# %%
MY_STAGING_SECRET = "a0a4d8f1a34501875101650ee2d60a2dc9dd27c38f0e1262a57ce7e1af1743a1" # Insert your API token here

# %%
STAGING_URL = "https://api.iarpagfchallenge.com"

import requests

secret_token = MY_STAGING_SECRET
server = STAGING_URL
url = server + '/api/v1/questions' # The endpoint to retrieve questions
headers = {'Authorization':'Bearer ' + secret_token}
params = {"training_data": "true"} # More to come on this in a moment

result = requests.get(url, headers=headers, params=params) 

if result.ok:
    j = result.json() # This will be the content you are interested in.
    ifp_count = len(j["questions"])
    print("We retrieved {} IFPs".format(ifp_count))
else:
    print('PROBLEM:', result.status_code, result.text)
# Out:
# We retrieved 10 IFPs

# %% [markdown]
# If your request is successful the variable `j` will hold a Python dict of the form {"questions": List of dicts} where each dict will contain the data for a single IFP.

# %% [markdown]
# When POSTing forecasts, things look pretty much the same, except it would be formatted with the `.post()` method, and the parameters would be submitted as `json`:
#
# `result = requests.post(url, headers=headers, json=params)`
#
# ### Passing parameters to the API
#
# Typically, you'll want to provide specific parameters when making your API calls, (e.g., asking for human forecasts made against a specific forecasting question, requesting information that has been updated since you last checked).  To do that, you will pass a set of parameters in python dictionary form.  The dictionary structure will be identical to the examples provided in the Cultivate API documentation.
#
# As an example, you may want to receive all human forecasts made against question number 5 since May 20, 2019. You would set your params dictionary as:
#
# `params = {'question_id':5, 'created_after':'2019-05-20T00:00:00.000Z'}`
#
# The full set of required and optional input parameters are listed in the Cultivate API documentation.
#
# ### Recieving Responses
#
# When a GET or POST request is successfully executed, you will receive a JSON formatted response which can be accessed as the response's `.json()` object.
#
# #### Paging
#
# All paginated endpoints will also include 2 pagination-related response headers: `X-Total-Page-Count` and `X-Total-Record-Count`. `X-Total-Page-Count` contains the total number of pages available for your request, while `X-Total-Record-Count` contains the total number of records that will be included across all of those pages.
#
# You can access these through the response's `headers` dictionary:
#
# ```
# result = requests.get(url, headers=headers, params=params)
#
# if result.ok:
#     totalPages = int(resp.headers.get('X-Total-Page-Count',0))
# ```
#
# By default, results are returned for the first page (page 0), updating the `params` dictionary to include `params['page'] = 1` would get the next page.
#
# ## Primary API Endpoints
#
# ### Retrieving Questions
#
# Individual Forecasting Problems (IFPs) are questions about future events that solvers forecast against, and can be retrieved from the `questions` API endpoint. Each IFP includes, among other fields, an `id` a `description`, a set of `answers`, and a collection of `metadata` as well as starting and ending dates. Questions can be retrieved using a GET request with optional parameters.  The `status` parameter (values: active, closed, all) describes whether an IFP is open for forecast submission.  The several date parameters `created_before`, `created_after`, `updated_before`, and `updated_after` limit the response based on when questions were updated or created. The `training_data` parameter is new to GF Challenge 2 and is used to retrieve IFPs that were part of the HFC program but are not in GF Challenge 2 and which are available for Solvers to train their methods.  (More below).  The `answers` are a list of mutually exclusive, and collectively exhaustive options describing possible IFP outcomes. Forecasts must specify probabilities for each possible outcome that sum to 1.0 (except for binary questions (e.g., yes/no) for which only one option is presented, with the other option being calculated as 1 - Option A).
#
# The `metadata` that is returned includes `Domain`, `Topic`, and location information. In GF Challenge 2 the metadata will only be populated as an IFP is closed.  (In the first GF Challenge this metadata was provided when an IFP was launched.)  This metadata is provided *post hoc* to allow Solvers to evaluate their techniques for identifying the region or subject of an IFP but does not figure into scoring in any way, as there are no Domain or Region prizes in GF Challenge 2.  Refer to the [GF Challenge 2 Rules document](NEEDS URL ONCE PUBLISHED) and the API documentation to ensure that you accurately retrieve and handle the relevant fields.
#
# Each IFP also includes a list of `clarifications`. This will be populated if there is additional guidance regarding the IFP issued. This can include situations where terms are further defined, or sources of resolution are changed. You should regularly check for updates to this field.
#
# ### Retrieving Individual and Aggregate Human Forecasts
#
# As part of the Challenge, solvers will have access to forecasts made by a crowd of human forecasters. These forecasts will be made available in two forms: individual and aggregate.  The individual forecasts are made available through the `prediction_sets` API end point, while the aggregate forecasts are provided through the `consensus_histories` end point. The consensus is calculated using an aggregation algorithm called logit. The logit aggregation method is an extremizing method that uses a weighted geometric mean to aggregate forecasts. Forecaster weights are calculated based on 3 factors: historical accuracy, the frequency with which the forecaster updates his or her forecasts, and whether the forecaster completed a training course. The `consensus_histories` data also serve as the baseline against which Solvers will be compared. More details on the baseline and scoring can be found in the official GF Challenge 2 Rules.
#
# Individual forecasts contain the probability forecasts, including a `question_id` that maps to the `id` in from the `questions` endpoint and `membership_guid` which uniquely identifies the human forecaster. Each forecast will include a list of `predictions` reflecting the probabilities that person assigned to each possible answer. The `forecasted_probability` for each answer represents that person's beliefs for each answer.
#
# Consensus aggregations contain a `question_id` and `answer_id` pair that identify a particular answer option. The `normalized_value` for a particular answer reflects the score such that all answers to a particular question will sum to 1.0. This consensus is updated any time a human forecaster makes a new forecast against an IFP. The `consensus_histories` API end point contains a list of these updated consensus scores. The most recent consensus for a particular question reflects the current crowd consensus at that time. NOTE: With the exception of the first time you query this endpoint, you should NOT retrieve `consensus_histories` without specifying a `created_after` parameter.
#
# ### Training Data (New in GF Challenge 2)
#
# There are two collections of non-competition training data that are available for Solvers to train and backtest their methods.  The training data on the Staging platform includes IFPs, individual human forecasts, and consensus histories for 86 IFPs between December 2018 and March 2019.  All of these IFPs are closed and have been resolved.  The training data on the Production platform consists of these elements for HFC IFPs that launched before the start of the GF Challenge 2 competition and which are not included in the Challenge.  Depending on when you access the Production training data you may have a mixture of open and closed IFPs, especially early in the Challenge.
#
# Please note that `membership_guid` values for the Staging training data will not be reused in GF Challenge 2.  However the `membership_guid` values in the Production platform training data will map to the same forecasters during the competition and are suitable for determining forecaster attributes such as accuracy and update frequency.
#
# ### Submitting Forecasts
#
# Forecast submission is done through an HTTP POST. Your forecast must include the `question_id`, an `external_predictor_attributes.method_name`, and `external_predictions_attributes`: a list of dictionaries each containing an `answer_id` and `value` for each of the forecast question's possible alternatives. The sum of the values must equal 1.0.
#
# Each Solver is allocated 40 methodological "slots." These slots can be used to represent different strategies for weighting data sources, different algorithms, etc. The `method_name` parameter is used to identify which slot a forecast should be associated with. `method_name` can be up to 50 characters, and will be held constant throughout the challenge (i.e., you cannot add a 41st method). You will be scored on a per `method_name` basis, with only your best performing approach being considered for each prize category. For more details, review the GF Challenge 2 rules.
#
# A forecast submission can look like:

# %% [markdown]
# ```
# params = {"external_prediction_set": {
#         "question_id": 123,
#         "external_predictor_attributes": {
#             "method_name": "red"
#             },
#         "external_predictions_attributes": [
#             {"value": 0.6, "answer_id": 431},
#             {"value": 0.35, "answer_id": 432},
#             {"value": 0.05, "answer_id": 433}
#             ]
#           }}
# ```

# %% [markdown]
# A successful submission of a forecast to the submission endpoint will return a json summary of the submission, including the time of submission. A failure (e.g., incorrect `answer_id` or `value`s that don't total to 1.0, or attempting to create a 41st `method_name`) will result in json describing the error. It is advisable to inspect the resulting json to ensure it reflects the intended forecast.
#
# ## Putting it All Together
#
# We can implement API access into a single Python class so we can make GET and POST requests in a consistent fashion.  Below, we define a `GfcApi` class that allows us to specify a server and API token one time and access all the API endpoints.

# %%
import requests
import time
import datetime

from pprint import pprint #This is just to make things look pretty...

#Make this python 2 and 3 compliant
from __future__ import print_function

class GfcApi(object):
    """
        An example class for interacting with the Geopolitical Forecasting Challenge 2
        API.  Note that this code is for reference purposes, no warranties are expressed
        or implied.  
    """
    def __init__(self,token,server,proxy=None,verbose=False):
        """
            Create an instance of an API client. This assumes you have an OAuth token.
            
            Arguments
            
            REQUIRED
            token - <string> - The secret API token assigned when registering on the 
                               Cultivate platform
            
            server - <string> - The beginning of the server url in the form:
                                https://api.XXXXXXX.com.  This is described in the
                                Cultivate API documentation
            
            OPTIONAL
            proxy - <dictionary> - If you are behind a proxy server, you can specify the details
                                   in the form: 
                                       proxy = {'http': http_proxy,
                                                'https': https_proxy,
                                                'ftp': ftp_proxy}
                                   where an individual entry might be [ip address:port]. See the
                                   requests library documentation for more details.
                Default: None
                
            verbose - <boolean> - If true, we print GET and POST request URLs and params
                Default: False
            
        """
        
        self.token = token
        self.server = server
        self.proxy = proxy
        self.verbose = verbose
        
        self.sess = requests.session()
        self.rate_limit_delay = 1 #seconds between subsequent API calls
        self.last_call_time = 0.0 
        self.set_urls()
    
    def set_urls(self):
        if not self.server.endswith('/'):
            self.server += '/'
    
        self.api_base = self.server + 'api/v1/'
    
        self.consensus_histories_url = self.server + 'aggregation/api/v1/control/consensus_histories'
        self.external_prediction_sets_url = self.api_base + 'external_prediction_sets'
        self.prediction_sets_url = self.api_base + 'control/prediction_sets'
        self.questions_url = self.api_base + 'questions'

    def get_questions(self, status=None, created_before=None, created_after=None,
                      sort='published_at', updated_before=None, updated_after=None,
                      training_data=False):
        """
            This function retrieves Individual Forecasting Problems (IFPs).

            Optional Inputs:
            status - <string> - IFP status
                    Possible Values:
                        'active' - only return questions that are currently open for forecasting
                        'closed' - return all resolved or otherwised closed questions
                        'all'    - return all active and closed questions
                    Default Value:
                        'active'

            created_before - <datetime> - returns only questions created before this time

            created_after - <datetime> - returns only questions created after this time
            
            sort - <string> - Sort order of returned questions
                    Possible Values:
                        'published_at'
                        'ends_at'
                        'resolved_at'
                        'prediction_sets_count'
                    Default Value:
                        'published_at'
            
            updated_before - <datetime> - returns only questions updated before this time
            
            updated_after - <datetime> - returns only questions updated after this time
            
            training_data - <boolean> - returns only the questions for the training data, 
                otherwise returns competition questions.  Default False.
                    
             Output:
            JSON representation of a list of Individual Forecasting Problems
        """
        
        url = self.questions_url
        section = 'questions'
        params={}
        
        if created_before:
            params['created_before'] = created_before.isoformat()
        if created_after:
            params['created_after'] = created_after.isoformat()
        if created_before:
            params['updated_before'] = updated_before.isoformat()
        if created_after:
            params['updated_after'] = updated_after.isoformat()
        if status:
            params['status'] = status
        if sort:
            params['sort'] = sort
        if training_data:
            params['training_data'] = 'true'
        
        return self._get_pages(url=url,section=section,params=params)
    
    def get_human_forecasts(self, question_id=None, created_before=None, created_after=None,
                           updated_before=None, updated_after=None, training_data=False):

        """
            This function retrieves the stream of human forecasts against IFPs.

            Optional Inputs:
            question_id - <integer> - returns predictions for a single question
                    Default Value:
                        None

            created_before - <datetime> - returns only predictions created before this time

            created_after - <datetime> - returns only predictions created after this time
            
            updated_before - <datetime> - returns only predictions updated before this time
            
            updated_after - <datetime> - returns only predictions updated after this time

            training_data - <boolean> - returns only the human forecasts for the training data, 
                    otherwise returns competition human forecasts.  Default is False.
                                        
             Output:
            JSON representation of a list of human forecasts
        """
        
        url = self.prediction_sets_url
        section = 'prediction_sets'
        params={}
        
        if created_before:
            params['created_before'] = created_before.isoformat()
        if created_after:
            params['created_after'] = created_after.isoformat()
        if updated_before:
            params['updated_before'] = updated_before.isoformat()
        if updated_after:
            params['updated_after'] = updated_after.isoformat()
        if question_id:
            params['question_id'] = question_id
        if training_data:
            params['training_data'] = "true"

       
        return self._get_pages(url=url,section=section,params=params)        
    
    def get_consensus_histories(self, question_id=None, created_before=None, created_after=None,
                           updated_before=None, updated_after=None, training_data=False):

        """
            This function retrieves the consensus of human forecasts against IFPs.

            NOTE: You need to include some date constraints after your first use of this API. 
            Always utilize the created_after parameter to pull only those records that have 
            been created since you last accessed the API. Do not attempt to pull every 
            record/page of the history.

            Optional Inputs:
            
            question_id - <integer> - returns only predictions made about a specific IFP
                Default Value
                    None

            created_before - <datetime> - returns only predictions created before this time

            created_after - <datetime> - returns only predictions created after this time
            
            updated_before - <datetime> - returns only predictions updated before this time
            
            updated_after - <datetime> - returns only predictions updated after this time
                    
            training_data - <boolean> - returns only the consensus histories for the training data, 
                 otherwise returns competition consensus histories.  
                 Default False.
                    
             Output:
            JSON representation of a list of human forecasts
        """
        
        if (not created_before) and (not created_after) and (not updated_before) and (not updated_after):
            print("After your first query, use a date constraint (created_before/after or",\
                  "updated_before/after) to get consensus history. Old values won't change")
        
        url = self.consensus_histories_url
        section = 'consensus_histories'
        params={}
        
        if question_id:
            params['question_id'] = str(question_id)
        if created_before:
            params['created_before'] = created_before.isoformat()
        if created_after:
            params['created_after'] = created_after.isoformat()
        if updated_before:
            params['updated_before'] = updated_before.isoformat()
        if updated_after:
            params['updated_after'] = updated_after.isoformat()
        if training_data:
            params['training_data'] = "true"

        
        return self._get_pages(url=url,section=section,params=params)   
    
    def submit_forecast(self,question_id,method_name,predictions):
        """
            Submit probabilistic forecasts against a question.
            
            Required Parameters
            
            question_id - <integer> - The question_id of the IFP being forecast against
            
            method_name - <string> - The name of one of your 25 forecasting methods. Up to 50 chars
                             NOTE: This is used to track and score your forecasting methods. You
                             are responsible for keeping track of your named methods. Using a new
                             method_name will automatically add a new method - unless you have
                             already created 25 methods. In that case, you'll get an error message
                             in the response.
                             
            predictions - <list> - A list of Dictionaries in the form .
                                                   {'answer_id': <Integer>, 'value': <Decimal>}
                            
                          If the question is binary (exactly two possible answers), you only submit a
                          prediction for one possible answer, with the other being equal to 1 minus
                          your prediction for option A.
                          
                          NOTE: The set of values in the forecast must equal exactly 1.0 or you will 
                          receive an error message in the response.
            
     RESPONSE
     The json response will either summarize your forecast to this question, or it will contain an 
     error message indicating why it wasn't accepted.  You are responsible for recieving and reviewing
     the response to ensure that your forecast was accepted, and reflects your intentions.  You can 
     resubmit forecasts to a particular IFP repeatedly over the course of a forecast day, and each
     new submission will replace older submissions for scoring purposes. Review the GF Challenge
     Rules for details on forecast submission and scoring.
        """
    
        url = self.external_prediction_sets_url
        
        params={'external_prediction_set':{'question_id':question_id,
                                          'external_predictor_attributes':
                                           {'method_name':method_name},
                                           'external_predictions_attributes':predictions}
                }
        
        return self._post(url,params)
    
    def _forecast_template(self,ifp):
        """
            A tiny little helper function to create the basis for the predictions parameter in
            the submit_forecast function.  You pass an IFP from the questions API into this 
            function and receive a list of 'answer_id' and 'value' dictionaries that are
            needed to submit a forecast.  
            
            NOTE: This sets the forecast probability (value field) to None, which will result in an error upon
            submission.  You must set this to a legal probability.
        """
        
        output = [{'answer_id':a['id'],'value':None} for a in ifp['answers']]
        return output
    
    def _get_pages(self,url,params,section):
        
        """
            This function uses _get to make authenticated calls to the
            relevant API endpoints with the user-provided parameters.
            
            This function handles paging through results, and returns only the list from
            the resulting json result(s).
            
            The 'url' and 'params' describe the API query, the 'section' is the key in the
            returned json that contains the list of query results (e.g., 'questions').
        """
        if self.verbose:
            print('Get Pages for {}'.format(url))
            print(params)
        page = 1
        maxPage = 1
        
        all_results = []
        this_batch = []
        while page <= maxPage: 
            
            params['page']=page
            resp = self._get(url=url,params=params)
            maxPage = int(resp.headers.get('X-Total-Page-Count',0))
            try:
                results=resp.json()
            except:
                results=None
            if isinstance(results,(list,dict)):
                if 'errors' in results:
                    print(results['errors'])
                    return results
                
                this_batch = results[section]
                all_results.extend(this_batch)

                page+=1
            else:
                if self.verbose:
                    print("PROBLEM")
                return results

        return all_results                
        
    def _get(self,url,params):
        """
            A helper function that handles authentication and rate limiting.
            
            Given a URL and a set of parameters, this function calls the Cultivate API
            and returns the json response.
        """
        
        while time.time() < self.last_call_time + self.rate_limit_delay:
            if self.verbose:
                print("{}: Sleeping".format(time.ctime()))
            time.sleep(1)
        
        headers={'Authorization':'Bearer ' + self.token} #This is needed to authenticate

        if self.verbose:
            print("{}: GETTING {}".format(time.ctime(),url))
            safeHeaders = {k:v for k,v in headers.items() if k!='Authorization'}
            safeHeaders['Authorization']="Bearer <shhhhhh it's a secret>"
            print("\tHeaders: {}".format(safeHeaders))
            print("\tArgs: {}".format(params))
        resp = self.sess.get(url, headers=headers, params=params, proxies=self.proxy)
                                                                                         
        self.last_call_time = time.time()
        return resp
    
    def _post(self,url,params):
        """
            A helper function that handles authentication.
            
            Given a URL and a set of parameters, this function submits a POST to the 
            Cultivate API and returns the json response.
            
            Output
            JSON response describing the forecast or indicating an error.

        """

        while time.time() < self.last_call_time + self.rate_limit_delay:
            if self.verbose:
                print("{}: Sleeping".format(time.ctime()))
            time.sleep(1)
        
        headers={'Authorization':'Bearer ' + self.token} #This is needed to authenticate

        if self.verbose:
            print("{}: POSTING {}".format(time.ctime(),url))
            safeHeaders = {k:v for k,v in headers.items() if k!='Authorization'}
            safeHeaders['Authorization']="Bearer <shhhhhh it's a secret>"
            print("\tHeaders: {}".format(safeHeaders))
            print("\tArgs: {}".format(params))
        resp = self.sess.post(url, headers=headers, json=params, proxies=self.proxy) 
                                                                                         
        self.last_call_time = time.time()
        
        return resp.json()

# %% [markdown]
# We can invoke this class by specifying our secret_token and server.
#
# One strategy for token management is to create a dictionary of server instances with the server address and API token like:

# %%
# Put your tokens in place of <STAGING API KEY> and <PRODUCTION API KEY> below.
secrets = {'staging':
              {'key':'<STAGING API KEY>',
               'server':'https://api.gfc-staging.com'},
           'production': 
              {'key':MY_STAGING_SECRET,
               'server':'https://api.iarpagfchallenge.com'}}

# %% [markdown]
# We can create an instance of the `GfcApi` class thusly:

# %%
instance='production'
gf=GfcApi(secrets[instance]['key'],secrets[instance]['server'],verbose=True)

# %% [markdown]
# Once we create an instance of the `GfcApi` class, we retrieve Individual Forecasting Problems (IFPs). We could limit our queries of IFPs based on several criteria:
#
# - Question status (active or not)
# - Date of creation or update (useful for finding clarifications)
# - Training data (true or false)
#
# The code snippet below illustrates using an instance of the GfcApi class to retrieve IFPs from the staging platform and to summarize them by extracting some of the fields from the IFP content.  In this example no filters were applied for `status`, creation or update dates, or `training_data`, so the query retrieves all non-training data IFPs on the platform.

# %%
ifps=gf.get_questions(training_data=True)
print("We've downloaded {} IFPs\n".format(len(ifps)))

for ifp in ifps:
    print("IFP {}: {}".format(ifp['id'],ifp['name']))
    print("Description: {}".format(ifp['description']))
    print("Starts: {}, Ends: {}".format(ifp['starts_at'],ifp['ends_at']))
    print("Options:")
    for answer in ifp['answers']:
        print(' ({}) {}'.format(answer['id'],answer['name']))
        
    if ifp['clarifications']:
        print('Clarifications:')
        print(ifp['clarifications'])
    print("")
# Out:
# Get Pages for https://api.iarpagfchallenge.com/api/v1/questions
# {'sort': 'published_at', 'training_data': 'true'}
# Wed Jun 12 16:16:11 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 1}
# Wed Jun 12 16:16:12 2019: Sleeping
# Wed Jun 12 16:16:13 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 2}
# Wed Jun 12 16:16:14 2019: Sleeping
# Wed Jun 12 16:16:15 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 3}
# Wed Jun 12 16:16:16 2019: Sleeping
# Wed Jun 12 16:16:17 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 4}
# Wed Jun 12 16:16:18 2019: Sleeping
# Wed Jun 12 16:16:19 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 5}
# Wed Jun 12 16:16:19 2019: Sleeping
# Wed Jun 12 16:16:20 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 6}
# Wed Jun 12 16:16:21 2019: Sleeping
# Wed Jun 12 16:16:22 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 7}
# Wed Jun 12 16:16:22 2019: Sleeping
# Wed Jun 12 16:16:23 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 8}
# Wed Jun 12 16:16:24 2019: Sleeping
# Wed Jun 12 16:16:25 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 9}
# Wed Jun 12 16:16:26 2019: Sleeping
# Wed Jun 12 16:16:27 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'training_data': 'true', 'page': 10}
# We've downloaded 95 IFPs
#
# IFP 1920: How many major hurricanes (Category 3 or above) will the Eastern Pacific Ocean experience between 24 May 2019 and 24 June 2019?
# Description: This question will be resolved using data from the National Hurricane Center (NHC), National Oceanic and Atmospheric Administration (NOAA) Tropical Cyclone Reports. To access the relevant data:
# - Go to <a href = "https://www.nhc.noaa.gov/data/tcr/"target="_blank">NHC Data</a>;
# - Click on the year of interest;
# - Click on 'Eastern Pacific';
# - Click on each map (there may be more than one) at the bottom of the page and count the number of Major Hurricanes (annotated 'MH') whose date range falls within or overlaps with the period of interest. Major Hurricanes are those hurricanes reaching Category 3 and higher. If the number of hurricanes crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question. This question will be resolved by consulting the data source between 10:00 AM ET Wednesday and 4:00 PM ET Thursday starting on 24 July 2019.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-06-24T18:01:00.000Z
# Options:
#  (5370) 0
#  (5369) 1
#  (5368) 2
#  (5367) More than 2
#
# IFP 1915: Between 9 May 2019 and 30 July 2019, will the IMF approve the release of a tranche of funds to Pakistan?
# Description: There is currently an "agreement in principle" on a bailout program between the International Monetary Fund (IMF) and Pakistan, though there are lingering issues to resolve (<a href = "https://www.thehindubusinessline.com/news/world/pakistan-holds-talks-with-imf-delegation-on-bailout-package/article27001263.ece"target="_blank">TheHinduBusinessLine</a>, <a href = "https://www.reuters.com/article/us-pakistan-imf/pakistan-reaches-agreement-in-principle-with-imf-over-bailout-idUSKCN1RR1C0"target="_blank">Reuters</a>, <a href = "https://www.bloomberg.com/news/articles/2019-04-18/pakistan-finance-minister-steps-down-from-cabinet-amid-imf-talks"target="_blank">Bloomberg</a>, <a href = "https://www.thestatesman.com/opinion/bailout-conundrum-1502747181.html)"target="_blank">TheStatesman</a> <a href = "https://www.imf.org/en/Countries/PAK)"target="_blank">IMFPakistan</a>).
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-07-30T18:01:00.000Z
# Options:
#  (5350) Yes, and it will be less than $2.5 billion
#  (5349) Yes, and it will be $2.5 billion or more
#  (5348) No
#
# IFP 1910: Will ACLED record any civilian fatalities in Iran between 14 June 2019 and 14 July 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
# The question will resolve as "yes" if ACLED records any event for which:
# - 'event_type' is "Violence against civilians" or "Explosions/Remote violence" AND;
# - 'actor2' includes "Civilians" AND;
# - 'fatalities' is greater than 0.
# If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-07-14T18:01:00.000Z
# Options:
#  (5335) Yes
#
# IFP 1905: What will be the last value of the EURO STOXX 50 Volatility Index VSTOXX (V2TX) on 31 July 2019?
# Description: This question will be resolved using the last value of the EURO STOXX 50 Volatility Index VSTOXX (V2TX) reported by STOXX Digital (<a href = "https://www.stoxx.com/index-details?symbol=V2TX"target="_blank">https://www.stoxx.com/index-details?symbol=V2TX</a>) for the date of interest. To access the relevant data:
# - Select 'Data';
# - Download 'Historical Data';
# - Refer to the 'Indexvalue' column for the date of interest.
# Question will be closed the day before the date of interest.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-07-30T18:01:00.000Z
# Options:
#  (5330) Less than 11.1
#  (5329) Between 11.1 and 12.8, inclusive
#  (5328) More than 12.8 but less than 14.3
#  (5327) Between 14.3 and 16, inclusive
#  (5326) More than 16
#
# IFP 1900: How many deaths perpetrated by Boko Haram will the Council on Foreign Relations report between 25 August 2019 and 25 November 2019?
# Description: The Council on Foreign Relations (CFR) <a href="https://www.cfr.org/nigeria/nigeria-security-tracker/p29483" target="_blank">Nigeria Security Tracker</a> reports on countrywide violence stemming from political, economic and social grievances. This question will be resolved using data reported by the CFR.  To access the relevant data, open the <a href="https://docs.google.com/spreadsheets/d/1_QY-l4xhMu5nZVluprOgRs6rUzgkkBemapdsg5lFzKU/pub?output=xlsx" target="_blank">CFR dataset</a> and refer to the sheet entitled 'NST Main Dataset.' The count of deaths for the period of interest is obtained by summing the 'Total Deaths' column for events in which Boko Haram is identified as a perpetrator (in the 'Boko Haram (P)' column) and 'Date' falls in the period of interest. If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-11-25T19:01:00.000Z
# Options:
#  (5305) Less than 310
#  (5304) Between 310 and 440, inclusive
#  (5303) More than 440 but less than 580
#  (5302) Between 580 and 780, inclusive
#  (5301) More than 780
#
# IFP 1895: What will be the average percentage cost of remitting $200 USD from Japan to China in Second Quarter 2019?
# Description: Remittances are defined here as the transfer of small amounts of money from an individual in one country to an individual in another country. These remittances are often initiated by foreign workers in one country to an individual in their home country. The World Bank provides data on the <a href= "https://remittanceprices.worldbank.org/en" target="_blank"> costs associated with transferring this money worldwide</a>. To access the relevant data:
# - Go to <a href="https://remittanceprices.worldbank.org/en/corridor/Japan/China"target="_blank">https://remittanceprices.worldbank.org/en/corridor/Japan/China</a>;
# - Above the table, on the right side, set 'Collection period for' to the period of interest;
# - Above the table, on the left side, set currency to 'USD';
# - Click the '200.00 USD' tab;
# - Percentage cost is located in the 'Total cost (%)' column in the 'Total Average' row at the bottom of the table.
# Note that the total average percent cost is the average cost of remitting on the 'Data collected on' date at the top right of the table, not the average for the entire quarter.  This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.  The question will be closed retroactively with the 'Data collected on' date as the end date of the question.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (5280) Less than 9.9
#  (5279) Between 9.9 and 11.4, inclusive
#  (5278) More than 11.4
#
# IFP 1890: Who will win India's Chandigarh Lok Sabha election?
# Description: The Chandigarh Lok Sabha election is scheduled for 19 May 2019.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-05-18T18:01:00.000Z
# Options:
#  (5265) Kirron Anupam Kher
#  (5264) Pawan Kumar Bansal
#  (5263) Harmohan Dhawan
#  (5262) Someone Else
#
# IFP 1885: What will be the status of the "Instability in Egypt" conflict on 26 November 2019 according to the Council on Foreign Relations' Global Conflict Tracker?
# Description: The Council on Foreign Relations (CFR) (<a href = "https://www.cfr.org/"target="_blank">https://www.cfr.org/</a>) monitors issues and conflicts around the world. The CFR's Center for Preventive Action (CPA)'s Global Conflict Tracker (<a href = "https://www.cfr.org/interactives/global-conflict-tracker#!/global-conflict-tracker"target="_blank">https://www.cfr.org/interactives/global-conflict-tracker#!/global-conflict-tracker</a>) provides an overview of conflicts occurring throughout the world. This question will be resolved according to the status of the indicated conflict as listed under the 'Conflict Status' section.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-11-25T19:01:00.000Z
# Options:
#  (5245) Worsening
#  (5244) Unchanging
#  (5243) Improving
#
# IFP 1880: Between 9 May 2019 and 29 November 2019, will a change in the membership of the Gulf Cooperation Council (GCC) be officially announced?
# Description: The six-member Gulf Cooperation Council includes Saudi Arabia, Bahrain, Qatar, Kuwait, Oman, and the United Arab Emirates (<a href = "http://www.gcc-sg.org/en-us/Pages/default.aspx"target="_blank">GCC1</a>, <a href = "http://www.gcc-sg.org/en-us/AboutGCC/MemberStates/Pages/Home.aspx"target="_blank">GCC2</a>). Amidst the Arab Spring, the GCC extended an invitation to Jordan and Morocco but neither became a member (<a href = "http://studies.aljazeera.net/en/dossiers/2015/03/201533171547520486.html"target="_blank">AlJazzera</a>). Meanwhile, Oman once threatened withdrawal (<a href = "https://www.arabianbusiness.com/oman-will-withdraw-from-gcc-over-security-pact-529776.html"target="_blank">ArabianBusiness</a>), and the ongoing crisis since 2017 between Qatar and other Council members leave some analysts wondering about the longevity of the Council (<a href = "https://www.petroleum-economist.com/articles/politics-economics/middle-east/2019/gulf-states-cooperation-quest-falters"target="_blank">PetroleumEconomist</a>, <a href = "http://www.arabnews.com/node/1185901/middle-east"target="_blank">ArabNews</a>). Only the announcement of a joining/leaving member(s) needs to occur during the question’s open period, not the act of joining/leaving itself.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (5227) Yes, only that one or more new member states will join the GCC
#  (5230) Yes, only that one or more member states will leave the GCC
#  (5229) Yes, both will be announced
#  (5228) No, neither will be announced
#
# IFP 1875: What will be the closing value of the Brazilian Real (BRL) to one U.S. Dollar exchange rate on 18 July 2019?
# Description: This question will be resolved using the closing value reported by Bloomberg for the date of interest.
# - Go to <a href="https://www.bloomberg.com/quote/USDBRL:CUR"target="_blank">Bloomberg</a>;
# - Click 'VIEW FULL CHART' above the chart on the right;
# - Click the one month time frame '1M'.
# Question will be closed the day before the date of interest.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-07-17T18:01:00.000Z
# Options:
#  (5210) Less than 3.818
#  (5209) Between 3.818 and 3.896, inclusive
#  (5208) More than 3.896 but less than 3.963
#  (5207) Between 3.963 and 4.041, inclusive
#  (5206) More than 4.041
#
# IFP 1870: Before 30 July 2019, will the government of Yemen and the Houthis agree on a concept of operations for phase 2 of redeployments under the Hodeidah Agreement?
# Description: In April 2019, the Government of Yemen and the Houthis agreed to phase 1 redeployments in and around the port city of Hodeidah (<a href = "https://thedefensepost.com/2019/04/15/yemen-houthis-hodeidah-plan-un/"target="_blank">TheDefensePost</a>, <a href = "https://www.un.org/press/en/2019/sc13785.doc.htm"target="_blank">UN1</a>, <a href = "https://www.reuters.com/article/us-yemen-security/u-n-envoy-sees-troop-withdrawal-in-yemens-hodeidah-within-weeks-idUSKCN1RU265"target="_blank">Reuters1</a>, <a href = "https://undocs.org/S/2018/1134"target="_blank">UNDocs</a>, <a href = "https://www.reuters.com/article/us-yemen-security-un/britain-urges-stronger-measures-at-u-n-if-no-progress-on-yemens-hodeidah-deal-idUSKCN1RR1VL"target="_blank">Reuters2</a>, <a href = "https://www.un.org/press/en/2019/sc13780.doc.htm"target="_blank">UN2</a>).
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (5185) Yes
#
# IFP 1865: Will the Aviation Safety Network record a hijacking or criminal occurrence between 21 May 2019 and 21 June 2019?
# Description: The <a href = "https://aviation-safety.net/"target="_blank">Aviation Safety Network (ASN)</a> covers accidents and safety issues regarding airliners, military transport planes and corporate jets. The ASN Safety Database contains detailed descriptions of over 20,300 incidents, hijackings and accidents. To access the relevant data:
# - Go to the <a href = "https://aviation-safety.net/database/"target="_blank">ASN Safety Database</a>;
# - Click on the year of interest.
# This question will resolve as "yes" if there is an incident with a 'H#' (Hijacking) or 'C#' (Criminal) under the 'cat' (category) column during the period of interest. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-06-21T18:01:00.000Z
# Options:
#  (5180) Yes
#
# IFP 1860: Will the WHO declare a Public Health Emergency of International Concern (PHEIC) between 9 May 2019 and 15 July 2019?
# Description: This question will resolve as "yes" if the World Health Organization (WHO) declares a PHEIC during the period of interest: <a href = "http://www.who.int/news-room/statements"target="_blank">WHO Statements</a>.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-07-15T18:01:00.000Z
# Options:
#  (5175) Yes
#
# IFP 1855: Will the UK's Prime Minister Theresa May experience a significant leadership disruption between 9 May 2019 and 15 October 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-10-15T18:01:00.000Z
# Options:
#  (5170) Yes
#
# IFP 1850: How many terrorist incidents with 15 or more dead (victims + perpetrators) will occur between 1 June 2019 and 30 June 2019 as reported by Wikipedia?
# Description: This question will be resolved using the number of terrorist incidents reported on Wikipedia's <a href = "https://en.wikipedia.org/wiki/List_of_terrorist_incidents"target="_blank">List of terrorist incidents</a> page in which 15 or more deaths, both victims and perpetrators, are reported to have occurred during the period of interest. If deaths are reported as a range for an incident, the lower bound will be used to determine if the event qualifies as 15 or more. This question will be resolved based on the data reported in Wikipedia at 11:59 PM ET on the day after the close date. If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (5165) Less than 12
#  (5164) Between 12 and 17, inclusive
#  (5163) More than 17
# Clarifications:
# [{'updated_at': '2019-06-03T18:45:02.831Z', 'content': 'This question will be resolved using the "List of terrorist incidents in June 2019" list accessible from the Wikipedia page: https://en.wikipedia.org/wiki/List_of_terrorist_incidents.  Other lists available from this page will not be consulted.', 'question_id': 1850, 'created_at': '2019-06-03T18:45:02.831Z', 'id': 135}]
#
# IFP 1845: Before 30 November 2019, will an agreement on the creation of a Middle East Strategic Alliance be signed?
# Description: Talks began in 2017 between Saudi Arabia, the United Arab Emirates, Bahrain, Kuwait, Oman, Qatar, Jordan, the United States, and Egypt about establishing the alliance (also called 'Arab NATO') (<a href = "https://carnegieendowment.org/2019/02/08/middle-east-strategic-alliance-has-long-way-to-go-pub-78317"target="_blank">CarnegieEndowment</a>). In April 2019, Egypt reportedly withdrew from discussions (<a href = "https://www.reuters.com/article/us-usa-mesa-egypt-exclusive/exclusive-egypt-withdraws-from-u-s-led-anti-iran-security-initiative-sources-idUSKCN1RM2WU"target="_blank">Reuters</a>). Variations of the name of the alliance will not affect resolution, and requirements for subsequent ratification are immaterial to the question.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (5150) Yes, with Egypt as a signatory
#  (5149) Yes, without Egypt as a signatory
#  (5148) No
#
# IFP 1840: Will there be a terrorist incident in France between 1 November 2019 and 20 November 2019 as reported by Wikipedia?
# Description: This question will be resolved as "yes" if a terrorist incident is reported to have occurred during the period of interest according to Wikipedia's <a href="https://en.wikipedia.org/wiki/List_of_terrorist_incidents_in_France"target="blank">List of terrorist incidents in France</a> page, based on the data reported at 11:59 PM ET on the day after the close date. If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question.
# Starts: 2019-05-08T16:30:00.000Z, Ends: 2019-11-20T19:01:00.000Z
# Options:
#  (5135) Yes
#
# IFP 1835: Will the Government of Canada issue a 'Level 2, 3, or 4' health notice for Venezuela between 2 May 2019 and 27 November 2019?
# Description: This question will be resolved using the Canadian government's <a href="https://travel.gc.ca/travelling/health-safety/travel-health-notices"target="blank">Travel health notices</a> for the country of interest. This question will resolve as "yes" if there is a qualifying travel health notice issued where "Date" is in the period of interest.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-27T19:01:00.000Z
# Options:
#  (5130) Yes
#
# IFP 1830: Will a high-altitude Electromagnetic Pulse (EMP) attack occur between 2 May 2019 and 30 October 2019?
# Description: As defined by the Congressional Research Service, a high-altitude <a href="http://www.dtic.mil/docs/citations/ADA480808"target="_blank">Electromagnetic Pulse (EMP)</a> is an instantaneous, intense energy field that can overload or disrupt at a distance numerous electrical systems and high technology microcircuits. A large scale EMP effect can be produced by a single nuclear explosion detonated high in the atmosphere. Credible media accounts suggesting that an EMP has been undertaken with deliberate intent will be sufficient to resolve the question as "yes."
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-10-30T18:01:00.000Z
# Options:
#  (5125) Yes
#
# IFP 1825: Will Algeria's Prime Minister Noureddine Bedoui experience a significant leadership disruption between 2 May 2019 and 31 August 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (5120) Yes
#
# IFP 1820: What will be the FAO Sugar Price Index in August 2019?
# Description: This question will be resolved using data reported by the Food and Agricultural Organization of the United Nations (FAO). Relevant data are available at <a href="http://www.fao.org/worldfoodsituation/foodpricesindex/en/"target="_blank"> http://www.fao.org/worldfoodsituation/foodpricesindex/en/</a> in the 'FAO food price index' table. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (5115) Less than 163
#  (5114) Between 163 and 175, inclusive
#  (5113) More than 175 but less than 186
#  (5112) Between 186 and 198, inclusive
#  (5111) More than 198
#
# IFP 1815: Who will win Malawi's presidential election?
# Description: The Malawian presidential election is scheduled for 21 May 2019, with the winner determined via a 'first-past-the-post' system.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-05-20T18:01:00.000Z
# Options:
#  (5086) Peter Mutharika
#  (5090) Lazarus Chakwera
#  (5089) Saulos Chilima
#  (5088) Atupele Muluzi
#  (5087) Someone else
#
# IFP 1810: How many earthquakes of magnitude 4.5 or stronger will occur in the Central America and the Caribbean area between 1 October 2019 and 31 October 2019?
# Description: This question will be resolved using the United States Geological Survey's Earthquake Catalog (<a href="https://earthquake.usgs.gov/earthquakes/search/"target="_blank">https://earthquake.usgs.gov/earthquakes/search/</a>). To access the relevant data:
# - Set the Magnitude to a Custom Minimum equal to the magnitude of interest;
# - Set the Date & Time to a Custom Start with the first day of interest and End to the last day of interest;
# - Leave the UTC times to the default settings (00:00:00 & 23:59:59);
# - Expand the 'Advanced Options';
# - Set Geographic Region to North=25, West=-110, East=-60, and South=10;
# - Click Search beneath Output Options.
#
# The number of earthquakes displays in the top left Search Results window. If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question. Because USGS often makes changes to its initial data (e.g. recorded magnitude), this question will be resolved by consulting the source between 10:00 AM and 4:00 PM ET on 2 December 2019. Resolution will be based on the value observed at the time of source consultation.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (5065) Less than 8
#  (5064) Between 8 and 16, inclusive
#  (5063) More than 16 but less than 22
#  (5062) Between 22 and 30, inclusive
#  (5061) More than 30
#
# IFP 1805: Will ACLED record any riots in Libya between 7 June 2019 and 7 July 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
#
# The question will resolve as "yes" if ACLED records any event for which 'event_type' is Riots. If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-07-07T18:01:00.000Z
# Options:
#  (5040) Yes
#
# IFP 1800: Will there be a 10% decrease in the daily closing price of the FTSE 100 over any five(5)-business day interval between 2 May 2019 and 20 November 2019?
# Description: This question will be resolved using the daily closing prices of the <a href="https://www.google.com/search?q=ftse+100"target="_blank">FTSE 100</a> reported by Google Finance. If a 10% decrease occurs, the question will be closed and resolved retroactively on the date the decrease occurred. This question will be resolved by consulting the data source between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-20T19:01:00.000Z
# Options:
#  (5035) Yes
#
# IFP 1795: How many patents will China publish that have International Patent Classification (IPC) code 'G09C' (CIPHERING OR DECIPHERING APPARATUS) in November 2019?
# Description: This question will be resolved using data from the European Patent Office. To access the relevant data:
# - Go to <a href="https://worldwide.espacenet.com/"target="_blank">Espacenet</a>;
# - Click on 'Advanced search' on the left of the page;
# - Verify that 'Worldwide – collection of published applications from 100+ countries' is selected in the collection search drop-down at the top;
# - Enter 'CN' in the 'Publication number' field;
# - Enter the year and month of interest in YYYYMM format in the 'Publication date' field;
# - Enter the IPC code of interest in the 'IPC' field;
# - Click 'Search.'
#
# The number of patents published is shown at the top of the 'Result list.'  If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (5030) Less than 5
#  (5029) Between 5 and 10, inclusive
#  (5028) More than 10
#
# IFP 1790: Between 2 May 2019 and 29 November 2019, will the Republic of Cyprus protest the presence of a Turkish drillship in Cyprus' southern continental shelf or EEZ?
# Description: The recent discovery of one of the largest gas resources off the coast of Cyprus may exacerbate the ongoing division between Greek and Turkish Cypriots and their respective guarantors, Greece and Turkey (<a href = "https://www.dailysabah.com/energy/2019/02/28/exxon-mobil-discovers-huge-natural-gas-reserve-off-cyprus"target="_blank">DailySabah1</a>, <a href = "http://www.ekathimerini.com/238350/article/ekathimerini/news/cyprus-protests-turkish-activity-in-its-eez"target="_blank">Ekathimerini</a>, <a href = "https://www.dailysabah.com/energy/2019/03/22/any-project-excluding-turkey-in-eastern-mediterranean-not-realistic"target="_blank">DailySabah2</a>). In support of Turkish Cypriots, Turkey announced they will begin sending drillships to the area for exploration (<a href = "https://www.aa.com.tr/en/economy/oil-and-gas-exploration-to-start-offshore-n-cyprus/1391548"target="_blank">AA</a>, <a href = "https://ahvalnews.com/gas-drilling/turkeys-second-drillship-arrives-marmara-sea"target="_blank">AhvalNews</a>, <a href = "https://maritimecyprus.com/2017/07/25/turkey-false-claims-on-cyprus-exclusive-economic-zone-eez/)"target="_blank">MaritimeCyprus</a>, <a href = "http://www.mfa.gov.cy/mfa/mfa2016.nsf/mfa86_en/mfa86_en?OpenDocument)"target="_blank">TurkeyMFA</a>). This question will resolve as 'yes' if the Republic of Cyprus protests the presence of a Turkish drillship in Cyprus' southern continental shelf or exclusive economic zone (EEZ) during the period of interest.
# Starts: 2019-05-01T16:30:19.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (5015) Yes
#
# IFP 1785: How many battle deaths will ACLED record in Ethiopia in November 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
# The count of battle deaths for the period of interest is obtained by summing the 'fatalities' column for events in which 'event_type' is Battles. If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question.  This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (5010) Less than 16
#  (5009) Between 16 and 32, inclusive
#  (5008) More than 32 but less than 56
#  (5007) Between 56 and 97, inclusive
#  (5006) More than 97
#
# IFP 1780: Before 30 November 2019, will former Sudanese President Omar Hassan Ahmad al-Bashir be surrendered to the International Criminal Court (ICC)?
#
# Description: The fate of former Sudanese President Omar Hassan Ahmad al-Bashir remains uncertain following his recent removal from power (<a href = "https://www.nytimes.com/2019/04/12/world/africa/sudan-al-bashir-extradition.html"target="_blank">NewYorkTimes</a>, <a href = "https://www.cnn.com/2019/04/12/africa/sudan-army-bashir-intl/index.html"target="_blank">CNN</a>, <a href = "https://www.nation.co.ke/news/africa/Bashir-ICC-extradition-up-to-civilian-govt--Sudan-says/1066-5073462-1107tww/"target="_blank">Nation</a>, <a href = "https://www.washingtonpost.com/politics/2019/04/15/four-things-know-about-sudans-coups/?utm_term=.abd2b304449c"target="_blank">WashingtonPost</a>).
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4985) Yes
#
# IFP 1775: According to the World Economic Forum’s 2019 Global Competitiveness Report, of the Republic of Korea, Thailand, and the United Arab Emirates, which will score highest for Pillar 8: Labour Market?
# Description: The Global Competitiveness Report is an annual report published by the World Economic Forum. Featuring the new Global Competitiveness Index 4.0, the report assesses the competitiveness landscape of 140 economies, providing unique insight into the drivers of economic growth in the era of the Fourth Industrial Revolution. This question will be resolved using the scores reported in The Global Competitiveness Report 2019. To access the relevant data:
# - Go to <a href = "http://www.weforum.org/gcr"target="_blank">http://www.weforum.org/gcr</a>;
# - Select the pillar of interest from the 'Index component' drop-down;
# - Compare scores of countries of interest.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (4980) Korea, Rep.
#  (4979) Thailand
#  (4978) United Arab Emirates
#  (4977) There will be a tie (between two, or all, countries)
#
# IFP 1770: Before 30 November 2019, will Georgia receive a NATO Membership Action Plan invitation and/or be designated an EU membership candidate/potential candidate?
# Description: Georgia has expressed its desire to join both NATO and the EU, but several outstanding issues remain, particularly related to Russia's role in the post-Soviet sphere (<a href = "https://www.bloomberg.com/news/articles/2019-04-05/brexit-is-georgia-s-chance-to-open-eu-entry-door-president-says"target="_blank">Bloomberg</a>, <a href = "https://www.theatlantic.com/international/archive/2019/04/west-georgia-nato/586225/?utm_source=feed"target="_blank">TheAtlantic</a>, <a href = "https://www.georgianjournal.ge/politics/35716-jens-stoltenberg-speaks-about-perspectives-of-georgias-nato-membership-furthering-relations.html"target="_blank">GeorgianJournal</a>, <a href = "https://www.reuters.com/article/us-russia-nato-georgia/russian-pm-warns-nato-admission-of-georgia-could-trigger-terrible-conflict-idUSKBN1KR1UQ"target="_blank">Reuters</a>). As of 1 May 2019, Bosnia and Herzegovina and North Macedonia are participants of a NATO Membership Action Plan (<a href = "https://www.nato.int/cps/en/natohq/topics_37356.htm"target="_blank">NATO</a>). As of 1 May 2019, Albania, Montenegro, North Macedonia, Serbia, and Turkey are candidates for EU membership, and Bosnia and Herzegovina and Kosovo are potential candidates (<a href = "https://ec.europa.eu/neighbourhood-enlargement/countries/check-current-status_en"target="_blank">Europa</a>).
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4960) Yes
#
# IFP 1765: Before 30 November 2019, will either house of India's Parliament vote on passage of a bill to repeal or amend Article 370 in India's Constitution?
# Description: Article 370 affords the Indian state of Jammu and Kashmir special autonomous status within the Indian union. Prior to elections commencing in April, Indian Prime Minister Narendra Modi and his Bharatiya Janata Party made a promise to repeal Article 370 (<a href = "https://timesofindia.indiatimes.com/elections/news/bjp-manifesto-reiterates-kashmir-stand-promises-to-repeal-articles-370-35a/articleshow/68778784.cms"target="_blank">TimesOfIndia</a>, <a href = "https://www.dailyo.in/politics/bjp-manifesto-sankalp-patra-article-370-article-35a-sanitary-pads-women-reservation-triple-talaq-narendra-modi-2019-general-elections-lok-sabha-elections/story/1/30239.html"target="_blank">DailyO</a>). The outcome of a vote is immaterial to the resolution.
# Starts: 2019-05-01T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4955) Yes
#
# IFP 1760: Before 30 July 2019, will a merger, acquisition, and/or joint venture agreement be announced between Telecom Italia and Open Fiber?
#
# Description: To create and provide a single ultrafast broadband service, Telecom Italia is exploring merging with smaller rival Open Fiber (<a href = "https://www.reuters.com/article/us-telecomitalia-agm-network-explainer/explainer-telecom-italia-at-crossroads-over-networks-future-idUSKCN1R920V"target="_blank">Reuters</a>, <a href = "https://www.bloomberg.com/news/articles/2019-02-02/italy-s-lender-favors-a-single-network-to-boost-economic-growth"target="_blank">Bloomberg</a>, <a href = "https://www.telecomitalia.com/tit/en/archivio/media/comunicati-stampa/telecom-italia/corporate/economico-finanziario/2019/TIM-Strategic-Plan.html"target="_blank">TelecomItalia</a>).
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (4950) Yes
#
# IFP 1755: How many aid workers will have been killed or kidnapped in Afghanistan between January 2019 and November 2019 according to the Aid in Danger (AiD) project?
# Description: The Aid in Danger (AiD) project collects information on events that interfere with the delivery of humanitarian aid (<a href = "http://www.insecurityinsight.org/aidindanger/digests/"target="_blank">http://www.insecurityinsight.org/aidindanger/digests/</a>). To access the relevant report:
# - Look under the header 'The Aid in Danger Monthly News Brief';
# - Select 'The Aid in Danger Monthly News Brief' for the latest month of interest;
# - Click 'Download.'
# The relevant data is listed in a table reporting the total number of aid workers reportedly affected during the period of interest in the 'Killed' and 'Kidnapped' columns. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-11-27T19:01:00.000Z
# Options:
#  (4945) Less than 6
#  (4944) Between 6 and 10, inclusive
#  (4943) More than 10 but less than 16
#  (4942) Between 16 and 20, inclusive
#  (4941) More than 20
#
# IFP 1750: Will the UN Security Council (UNSC) issue a press statement concerning violence in Sudan between 25 April 2019 and 29 November 2019?
# Description: The UNSC press statement must explicitly reference the country of interest (or a location within the country) as a location of recent violence, including but not limited to terrorist attacks, military attacks, sectarian violence, violent civil unrest, or acts of government violence. The date on the statement will be used without any time zone conversion. This question will be resolved based on the press statements published on the UN website: <a href = "https://www.un.org/securitycouncil/content/statements-made-press-president-security-council-2019"target="_blank">UNSC press statements</a>.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4920) Yes
#
# IFP 1745: What will be the average percentage cost of remitting $200 USD from Saudi Arabia to Syria in Third Quarter 2019?
# Description: Remittances are defined here as the transfer of small amounts of money from an individual in one country to an individual in another country. These remittances are often initiated by foreign workers in one country to an individual in their home country. The World Bank provides data on the <a href= "https://remittanceprices.worldbank.org/en" target= "_blank"> costs associated with transferring this money worldwide</a>. To access the relevant data:
# - Go to <a href= "https://remittanceprices.worldbank.org/en/corridor/Saudi%20Arabia/Syria"target="_blank">https://remittanceprices.worldbank.org/en/corridor/Saudi%20Arabia/Syria</a>;
# - Above the table, on the right side, set ‘Collection period for’ to the period of interest;
# - Above the table, on the left side, set currency to ‘USD’;
# - Click the ‘200.00 USD’ tab;
# - Percentage cost is located in the ‘Total cost (%)’ column in the ‘Total Average’ row at the bottom of the table.
#
# Note that the total average percent cost is the average cost of remitting on the ‘Data collected on’ date at the top right of the table, not the average for the entire quarter.  This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.  The question will be closed retroactively with the ‘Data collected on’ date as the end date of the question.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-09-30T18:01:00.000Z
# Options:
#  (4915) Less than 19
#  (4914) Between 19 and 26, inclusive
#  (4913) More than 26
#
# IFP 1740: Will any country's national military launch a nuclear weapon at any other country between 25 April 2019 and 20 November 2019?
# Description: Any method of nuclear weapon delivery (to include the attempted use of an improvised nuclear weapon (e.g., so-called "dirty bomb") credibly attributed to a national military will qualify as a "launch." Actions by non-state actors will not qualify as "national military" actions. The weapon need not successfully detonate or reach its intended or presumed target to result in a "yes" resolution.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-11-20T19:01:00.000Z
# Options:
#  (4900) Yes
#
# IFP 1735: Will the Philippines execute or be targeted in a national military attack between 25 April 2019 and 15 August 2019?
# Description: A "national military attack" includes the employment of conventional or unconventional weapons by one country's national military forces (to include special forces) on another country's military, military assets, or territory, including citizens located within that territory, but excluding territorial waters, foreign missions, and/or exclusive economic zones. A "cyber" attack will not qualify as a "national military attack."
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-08-15T18:01:00.000Z
# Options:
#  (4895) Yes
#
# IFP 1730: Will North Korea's Supreme Leader Kim Jong Un experience a significant leadership disruption between 25 April 2019 and 10 November 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-11-10T19:01:00.000Z
# Options:
#  (4890) Yes
#
# IFP 1725: Will Israel's Prime Minister Benjamin Netanyahu experience a significant leadership disruption between 25 April 2019 and 29 November 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4885) Yes
#
# IFP 1720: Will the International Crisis Group report an unchanged, deteriorated, or improved situation for Sudan in June 2019?
# Description: The International Crisis Group's monthly bulletin, Crisis Watch, provides short, country-specific updates on political and security developments worldwide, assessing in each case whether the overall situation has deteriorated, improved, or remained unchanged. The question will resolve according to conflict status for the country of interest for the period of interest as reported within the International Crisis Group’s Crisis Watch Map.  To access the relevant information:
#
# - Go to <a href = "https://www.crisisgroup.org/crisiswatch"target="_blank"> https://www.crisisgroup.org/crisiswatch</a>;
# - Click on 'BROWSE MAP';
# - Click on the country of interest;
# - Hover over the lines at the top of the pop-up window for the status of the period of interest.
#
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (4880) Deteriorated
#  (4879) Unchanged
#  (4878) Improved
#
# IFP 1715: According to the Global Disaster Alert and Coordination System (GDACS), will there be any Red alerts for tropical cyclones for India between 25 April 2019 and 27 November 2019?
# Description: This question will resolve as 'yes' if the Global Disaster Alert and Coordination System reports a Red tropical cyclone alert for India during the period of interest. To access the relevant data:
# - Go to <a href = "http://www.gdacs.org/Alerts/default.aspx"target="_blank">GDACS Alerts</a>
# - Click ‘Search’;
# - Select the event of interest;
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Select ‘Level’ to Red;
# - Click ‘Submit’.
#
# This question will be resolved by consulting the data source sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, after the question close date.
# Starts: 2019-04-24T16:30:00.000Z, Ends: 2019-11-27T19:01:00.000Z
# Options:
#  (4865) Yes
#
# IFP 1710: What will be Neuquén's oil production in August 2019?
# ...
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-04-30T18:01:00.000Z
# Options:
#  (4330) Less than $1.50
#  (4329) Between $1.50 and $2.75, inclusive
#  (4328) More than $2.75 but less than $4.00
#  (4327) Between $4.00 and $5.50, inclusive
#  (4326) More than $5.50
#
# IFP 1520: Will the Government of Canada issue a travel advisory of "Exercise a high degree of caution," "Avoid non-essential travel," or "Avoid all travel" for New Zealand between 4 April 2019 and 12 June 2019?
# Description: This question will be resolved using the Canadian government's <a href="https://travel.gc.ca/destinations/new-zealand"target="blank">Travel health notices</a> for the country of interest. This question will resolve as "yes" if there is a qualifying travel health notice where the 'Last updated' date is in the period of interest.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-06-12T18:01:00.000Z
# Options:
#  (4305) Yes
#
# IFP 1515: Before 30 July 2019, will the Russian Duma approve the "sovereign Internet" bill (Bill No. 608767-7)?
# Description: In 2018, legislators introduced in the Russian Duma Bill No. 608767-7, being called by some the "sovereign Internet" bill (<a href = "http://sozd.duma.gov.ru/bill/608767-7"target=_blank">Duma</a> [in Russian]). This legislation would increase state authority to control the Internet in the country and has drawn protests (<a href = "https://www.polygraph.info/a/russia-sovereign-internet-great-firewall/29768477.html"target=_blank">Polygraph</a>, <a href = "https://codastory.com/news/russias-next-step-for-toward-sovereign-internet/"target=_blank">CodaStory</a>, <a href = "https://www.themoscowtimes.com/2019/02/01/russia-flirts-with-internet-sovereignty-op-ed-a64369"target=_blank">The Moscow Times</a>, <a href = "https://www.npr.org/2019/03/11/702347714/russians-fearing-internet-isolation-protest-government-plan"target=_blank">NPR</a> , <a href = "https://www.bloomberg.com/news/articles/2019-03-05/vladimir-putin-wants-his-own-internet"target=_blank">Bloomberg</a>). The bill passed first reading in February 2019; if the majority of parliamentarians vote in favor of the draft law in the third reading, it is considered approved (<a href = "http://duma.gov.ru/news/29748/"target=_blank">Duma news 1</a> [in Russian],  <a href = "https://www.rferl.org/a/russian-bill-on-autonomous-operation-of-internet-advances-in-duma/29765882.html"target=_blank">rferl</a>,  <a href = "http://duma.gov.ru/en/news/28319/"target=_blank">Duma news 2</a>,  <a href = "http://old.themoscowtimes.com/sitemap/free/1997/9/article/how-bill-becomes-law-in-russia/301058.html"target=_blank">Duma bill process</a>).
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (4300) Yes
#
# IFP 1510: When will Russia release Michael Calvey?
# Description: Michael Calvey, an American investor who had been working in Russia for decades, was arrested in February 2019 and charged with fraud (<a href = "https://www.bloomberg.com/news/articles/2019-02-19/investors-wonder-who-is-safe-in-russia-after-fund-manager-arrest"target=_blank">Bloomberg</a>). He is awaiting a trial that is scheduled to start in mid-April (<a href = "https://www.ft.com/content/f993bee6-43e4-11e9-b168-96a37d002cd3"target=_blank">Financial Times</a>,  <a href = "http://www.intellinews.com/moscow-blog-businesses-threaten-to-boycott-the-st-petersburg-investment-summit-as-michael-calvey-does-his-first-month-in-jail-157879"target=_blank">intellinews</a>,  <a href = "https://www.themoscowtimes.com/2019/02/28/russian-court-denies-detained-us-investor-calvey-bail-a64665"target=_blank">Moscow Times</a>). Release with restrictions (e.g. house arrest, bail) will not count.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4295) Before 1 May 2019
#  (4294) Between 1 May 2019 and 6 June 2019
#  (4293) Between 7 June 2019 and 31 August 2019
#  (4292) Between 1 September 2019 and 29 November 2019
#  (4291) Not before 30 November 2019
#
# IFP 1505: Will there be a biological attack resulting in multiple human casualties between 4 April 2019 and 27 November 2019?
# Description: A biological attack is defined as the intentional release of a pathogen (disease-causing agent) or biotoxin (poisonous substance produced by a living organism) by a government, military, paramilitary, terrorist, or criminal entity that results in unwanted harm/damage to a human, plant, or animal. A "yes" resolution requires that the media reports that the event is consistent with an intentional act and that multiple humans (excluding alleged perpetrators) are sickened, injured or killed in conjunction with the attack.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-11-27T19:01:00.000Z
# Options:
#  (4270) Yes
#
# IFP 1500: Will the PITF Worldwide Atrocities Dataset record an event perpetrated by a non-state actor in South Africa (ZAF) that starts between 3 April 2019 and 30 April 2019?
# Description: This question will resolve as "yes" if the Political Instability Task Force (<a href="http://eventdata.parusanalytics.com/data.dir/atrocities.html">PITF</a>) Worldwide Atrocities Dataset records any event with a start date (Start Day, Start Month, Start Year) in the period of interest, inclusive, for which 'Event Location: Country' is the country of interest, and 'Perpetrators: Perp State Role' is: 'Multiple Perpetrators (Non-State)'; 'Non-State, Internal, No State Sanction'; 'Transnational, Non-State'; or 'Unknown/Unclear/Other'. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-04-30T18:01:00.000Z
# Options:
#  (4265) Yes
#
# IFP 1495: Will Venezuela execute or be targeted in a national military attack between 3 April 2019 and 17 April 2019?
# Description: A "national military attack" includes the employment of conventional or unconventional weapons by one country's national military forces (to include special forces) on another country's military, military assets, or territory, including citizens located within that territory, but excluding territorial waters, foreign missions, and/or exclusive economic zones. A "cyber" attack will not qualify as a "national military attack."
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-04-17T18:01:00.000Z
# Options:
#  (4260) Yes
#
# IFP 1490: What will be the Korean Central News Agency (KCNA) Threat Index on 10 June 2019?
# Description: The <a href="https://kcnawatch.co/"target="_blank">KCNA Watch</a> database's Threat Index is a daily measure of the number of threatening English language words published each day by the KCNA, divided by the number of English language articles published by the KCNA on that date.  The Threat Index for a particular date can be found by hovering your cursor over the Threat Index chart line on the KCNA Watch homepage.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-06-09T18:01:00.000Z
# Options:
#  (4255) Less than 0.2
#  (4254) Between 0.2 and 0.4, inclusive
#  (4253) More than 0.4 but less than 0.6
#  (4252) Between 0.6 and 0.8, inclusive
#  (4251) More than 0.8
#
# IFP 1485: Which country will account for the largest performance share in computational power in the June 2019 TOP500 list of highest-performing computer systems?
# Description: The  <a href = "https://www.top500.org/lists/"target="_blank">TOP500 list of the highest-performing computing systems</a> is published twice per year, generally in June and November. Question will be resolved according to the data associated with the June 2019 TOP500 list.  To access the data, visit  <a href = "https://www.top500.org/statistics/list/"target="_blank">https://www.top500.org/statistics/list/</a>:
#
# - Select 'June 2019' from the 'TOP500 Release' drop down menu;
# - Select 'Countries' in the 'Category' drop down menu.
# - Click 'Submit.'
#
# Question will be resolved according to the data illustrated in the 'Countries Performance Share' pie chart.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-05-31T18:01:00.000Z
# Options:
#  (4230) China
#  (4229) US
#  (4228) All other countries combined
# Clarifications:
# [{'updated_at': '2019-04-04T16:15:02.890Z', 'content': 'We identified a formatting error within the hyperlinks in question #503 (TOP500) and have corrected the issue. ', 'question_id': 1485, 'created_at': '2019-04-04T16:15:02.890Z', 'id': 125}]
#
# IFP 1480: Will there be a significant day-over-day increase in worldwide search interest in the term "explosion" reported by Google Trends between 4 April 2019 and 17 April 2019?
# Description: Google Trends tracks how often a particular search-term is entered relative to the total search-volume. Values represent search interest relative to the highest value for the given region and period of interest. A value of 100 is the peak popularity for the term during the period of interest. A value of 50 means that the term is half as popular. A score of 0 means there was not enough data for this term. This question will resolve as 'yes' if Google Trends shows a 50-point or greater increase of interest in the search term in one (1) day during the period of interest. To access the relevant data, from <a href= "https://trends.google.com/trends/explore"target="_blank">Google Trends</a>:- Enter the search term of interest (as a 'Search term' not a 'Topic');- Make sure 'Worldwide' is selected for the geographic area;- Use the drop-down field to enter a 'Custom time range' corresponding to the period of interest;- Click the down arrow in the top right of the 'Interest over time' chart to download the data to a CSV file.This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-04-17T18:01:00.000Z
# Options:
#  (4215) Yes
#
# IFP 1475: Who will win the Philippines' Bohol gubernatorial election?
# Description: The Bohol gubernatorial election is scheduled for 13 May 2019.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-05-12T18:01:00.000Z
# Options:
#  (4210) Hercules Castillo
#  (4209) Leoncio Evasco Jr.
#  (4208) Concepcion Flores
#  (4207) Roberto Reyes
#  (4206) Arthur Yap
#
# IFP 1470: How many battle deaths will ACLED record in Niger between 4 April 2019 and 14 April 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
#
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
#
# The count of battle deaths for the period of interest is obtained by summing the 'fatalities' column for events in which 'event_type' is Battle. If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question.
#
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-04-14T18:01:00.000Z
# Options:
#  (4185) None
#  (4184) Between 1 and 3, inclusive
#  (4183) More than 3 but less than 7
#  (4182) Between 7 and 21, inclusive
#  (4181) More than 21
#
# IFP 1465: Before 30 November 2019, will Libya set a date or dates for parliamentary and/or presidential elections?
# Description: Libyan elections were set for 10 December 2018 but postponed due to a rise in violence (<a href = "https://www.washingtonpost.com/world/africa/un-says-libya-factions-to-meet-in-tripoli-over-elections/2019/03/20/0847f518-4b0d-11e9-8cfc-2c5d0999c21e_story.html"target=_blank">Washington Post</a>,  <a href = "https://www.reuters.com/article/us-libya-security/libya-to-hold-elections-by-year-end-tripoli-pm-idUSKCN1QM2QC"target=_blank">Reuters</a>,  <a href = "https://me-confidential.com/19556-libyan-rivals-agree-to-hold-elections-december-10.html"target=_blank">ME Confidential</a>). The date elections are set for, or held, is immaterial, providing setting either/both occurs before the question closes.
# Starts: 2019-04-03T16:30:09.000Z, Ends: 2019-11-29T19:01:25.000Z
# Options:
#  (4160) Yes, both parliamentary and presidential
#  (4159) Yes, only parliamentary
#  (4158) Yes, only presidential
#  (4157) No date for either presidential or parliamentary elections will be set before 30 November 2019
#
# IFP 1460: Before 1 May 2019, will Mexico's Senate approve President López Obrador's constitutional reform proposal on a presidential recall referendum?
# Description: Mexico's Chamber of Deputies (lower house) passed the reform in mid-March 2019, making it one step closer to becoming law. The reform allows for a mid-term presidential recall referendum (<a href = "https://www.reuters.com/article/us-mexico-politics/mexicos-lower-house-passes-measure-to-cut-short-presidential-term-idUSKCN1QW0FC"target=_blank">Reuters</a>,  <a href = "https://thehill.com/opinion/international/433848-amlo-cant-bend-mexicos-economy-to-his-will-like-he-can-its-political"target=_blank">The Hill</a>,  <a href = "https://mexiconewsdaily.com/news/lopez-obrador-vows-to-sign-accord/"target=_blank">Mexico News Daily</a>,  <a href = "http://www.senado.gob.mx/64/votaciones"target=_blank">Senate Votes</a>, <a href = "http://www.senado.gob.mx/64/sobre_el_senado/proceso_legislativo"target=_blank">Legislative Process</a>).
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-04-30T18:01:00.000Z
# Options:
#  (4140) Yes
#
# IFP 1455: Will France's President Emmanuel Macron experience a significant leadership disruption between 3 April 2019 and 29 November 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (4135) Yes
#
# IFP 1450: Will WHO release a Disease Outbreak News (DON) report about cholera in Democratic Republic of the Congo between 10 April 2019 and 25 May 2019?
# Description: The World Health Organization (WHO) publishes <a href="http://www.who.int/csr/don/en/">Disease Outbreak News (DONs)</a> about epidemic emergency preparedness and response worldwide. Question will resolve as "yes" if WHO publishes a DON with the disease and country of interest in the headline during the time period of interest. References in the headline to specific areas of the country of interest will result in a "yes" resolution. References in the headline to multinational regions will result in a "yes" resolution if the country of interest or its territory is explicitly named somewhere in the news item.
# Starts: 2019-04-03T16:30:00.000Z, Ends: 2019-05-25T18:01:00.000Z
# Options:
#  (4130) Yes

# %%
ifps=gf.get_questions(training_data=False)
print("We've downloaded {} IFPs\n".format(len(ifps)))

for ifp in ifps:
    print("IFP {}: {}".format(ifp['id'],ifp['name']))
    print("Description: {}".format(ifp['description']))
    print("Starts: {}, Ends: {}".format(ifp['starts_at'],ifp['ends_at']))
    print("Options:")
    for answer in ifp['answers']:
        print(' ({}) {}'.format(answer['id'],answer['name']))
        
    if ifp['clarifications']:
        print('Clarifications:')
        print(ifp['clarifications'])
    print("")
# Out:
# Get Pages for https://api.iarpagfchallenge.com/api/v1/questions
# {'sort': 'published_at'}
# Wed Jun 12 16:16:27 2019: Sleeping
# Wed Jun 12 16:16:28 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 1}
# Wed Jun 12 16:16:29 2019: Sleeping
# Wed Jun 12 16:16:30 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 2}
# Wed Jun 12 16:16:30 2019: Sleeping
# Wed Jun 12 16:16:31 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 3}
# Wed Jun 12 16:16:33 2019: Sleeping
# Wed Jun 12 16:16:34 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 4}
# Wed Jun 12 16:16:35 2019: Sleeping
# Wed Jun 12 16:16:36 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 5}
# Wed Jun 12 16:16:38 2019: Sleeping
# Wed Jun 12 16:16:39 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 6}
# Wed Jun 12 16:16:40 2019: Sleeping
# Wed Jun 12 16:16:41 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 7}
# Wed Jun 12 16:16:41 2019: Sleeping
# Wed Jun 12 16:16:42 2019: GETTING https://api.iarpagfchallenge.com/api/v1/questions
# 	Headers: {'Authorization': "Bearer <shhhhhh it's a secret>"}
# 	Args: {'sort': 'published_at', 'page': 8}
# We've downloaded 80 IFPs
#
# IFP 2355: Will there be a 10% decrease in the daily closing price of the EURONEXT N100 over any interval of five or fewer business days between 13 June 2019 and 29 November 2019?
# Description: This question will be resolved using the daily closing prices of the <a href="https://www.google.com/search?q=INDEXEURO:+N100"target="_blank">EURONEXT N100</a> reported by Google Finance. If a 10% decrease occurs, the question will be closed and resolved retroactively on the date the decrease occurred. This question will be resolved by consulting the data source sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6550) Yes
#
# IFP 2350: Who will be Prime Minister of the United Kingdom on 30 July 2019?
# Description: UK Prime Minister Teresa May resigned as Tory leader on 7 June 2019, and will stay on as PM until her replacement is determined (<a href = "https://www.bbc.com/news/uk-politics-48395905"target="_blank">BBC</a>, <a href = "https://www.theatlantic.com/international/archive/2019/05/who-will-be-britains-next-prime-minister-cheat-sheet/590518/"target="_blank">TheAtlantic</a>, <a href = "https://www.theguardian.com/politics/ng-interactive/2019/may/28/tory-leadership-contest-odds-tracker-whos-up-and-whos-down"target="_blank">TheGuardian</a>). This question will resolve based on circumstances at 11:59:59pm ET on 30 July.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (6545) Michael Gove
#  (6544) Jeremy Hunt
#  (6543) Boris Johnson
#  (6542) Dominic Raab
#  (6541) Some other outcome
#
# IFP 2345: Will Iran's President Hassan Rouhani experience a significant leadership disruption between 13 June 2019 and 5 October 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
#
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-10-05T18:01:00.000Z
# Options:
#  (6520) Yes
#
# IFP 2340: Will the European Union file a World Trade Organization dispute against any country/territory between 13 June 2019 and 29 November 2019?
# Description: This question will resolve as "yes" if the World Trade Organization (WTO) reports a dispute with the European Union as the complainant and any country as the respondent during the period of interest. To access the list of trade disputes:
# - Go to  <a href = "https://www.wto.org/english/tratop_e/dispu_e/find_dispu_cases_e.htm"target="_blank">WTO Disputes</a>;
# - Select '2019' as the 'Year dispute was brought to the WTO';
# - Select 'European Union (formerly EC)' 'as complainant';
# - Select 'Any country/territory' 'as respondent';
# - Click 'Search'.
# The dispute cases that match the entered criteria are displayed. The dispute case’s 'Request for Consultations' date will be used as the dispute filing date.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6515) Yes
#
# IFP 2335: What will be the monthly period-over-period change in the consumer price index (CPI) for China, P.R.: Mainland in June 2019?
# Description: This question will be resolved using data from the International Monetary Fund (<a href = "http://data.imf.org/regular.aspx?key=61015893"target="_blank">http://data.imf.org/regular.aspx?key=61015893</a>). To access the relevant data:
# - Select the country of interest from the Country drop down menu;
# - Select 'Consumer Price Index, All items' from the Indicator drop down menu.
# The relevant row is 'China, P.R.: Mainland, Consumer Price Index, All items,' and the relevant column is '2019M06.' This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (6510) Less than -0.4
#  (6509) Between -0.4 and 0, inclusive
#  (6506) More than 0 but less than 0.4
#  (6507) Between 0.4 and 0.8, inclusive
#  (6508) More than 0.8
#
# IFP 2330: Will the Basel Institute of Governance indicate that Saudi Arabia has a lower, unchanged, or higher risk of money laundering / terrorist financing in 2019 compared to 2018?
# Description: The Basel Institute of Governance generates an annual Basel AMT Index score that indicates a country's risk of money laundering / terrorist financing for a given year, with a higher score indicating a greater risk of money laundering / terrorist financing. This question will be resolved using the Basel Institute of Governance’s "Basel AML Index 2019 Report" due to be released in the Third Quarter 2019.  The report for 2018 indicates Saudi Arabia had a score of 5.01. To access the relevant data:
# - Go to <a href = "https://www.baselgovernance.org/asset-recovery/basel-aml-index"target="_blank">Basel AML Index</a>;
# - Locate the "Basel AML Index 2019 Report";
# - Locate the link to download a PDF version of the report;
# - Within the report, locate the scores and rankings section for 2019 and the country of interest.
# The question will be resolved according to the 'score' for that country. If the report is released prior to the close date, the question will be retroactively resolved on the date of the report.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-09-30T18:01:00.000Z
# Options:
#  (6485) Lower
#  (6484) Unchanged
#  (6483) Higher
#
# IFP 2325: Will the Aviation Safety Network record a hijacking or criminal occurrence between 22 June 2019 and 22 July 2019?
# Description: The <a href = "https://aviation-safety.net/"target="_blank">Aviation Safety Network (ASN)</a> covers accidents and safety issues regarding airliners, military transport planes and corporate jets. The ASN Safety Database contains detailed descriptions of over 20,300 incidents, hijackings and accidents. To access the relevant data:
# - Go to the <a href = "https://aviation-safety.net/database/"target="_blank">ASN Safety Database</a>;
# - Click on the year of interest.
# This question will resolve as "yes" if there is an incident with a 'H#' (Hijacking) or 'C#' (Criminal) under the 'cat' (category) column during the period of interest.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-07-22T18:01:00.000Z
# Options:
#  (6470) Yes
#
# IFP 2320: Will Ukraine's President Volodymyr Zelensky experience a significant leadership disruption between 13 June 2019 and 29 November 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6465) Yes
#
# IFP 2315: Before 1 July 2019, will the European Commission (EC) extend Switzerland's stock market equivalence status?
# Description: In December 2018, the EC extended Switzerland's "equivalence" status for regulatory purposes, making stock market trading easier between the country and the EU (<a href = "http://europa.eu/rapid/press-release_IP-18-6801_en.htm"target="_blank">Europa</a>, <a href = "https://www.economist.com/finance-and-economics/2019/05/11/the-eu-tries-to-strong-arm-switzerland-into-a-new-trade-deal"target="_blank">Economist</a>, <a href = "https://www.eda.admin.ch/dea/en/home/aktuell/medienmitteilungen.html/content/dea/en/meta/news/2018/12/20/73520"target="_blank">EuropeanAffairs</a>). The current granting of the status is set to expire at the end of June as Switzerland and the EU work to finalize an agreement for the Swiss to align its laws with the EU (<a href = "https://www.reuters.com/article/us-swiss-eu/two-thirds-of-swiss-companies-want-treaty-with-eu-poll-idUSKCN1SY1OJ"target="_blank">Reuters</a>, <a href = "https://www.bloomberg.com/news/articles/2019-05-19/swiss-face-next-eu-hurdle-after-falling-in-line-on-guns-and-tax"target="_blank">Bloomberg</a>).
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (6460) Yes
#
# IFP 2310: Between 13 June 2019 and 29 July 2019, will budget protests in Lebanon result in a fatality?
# Description: Recent economic reform proposals, including but not limited to public sector wage reductions and military pension cuts, have incited protests since mid-April 2019 (<a href = "https://www.alaraby.co.uk/english/news/2019/5/21/hundreds-of-lebanese-protest-feared-pension-cuts"target="_blank">TheNewArab</a>, <a href = "https://www.france24.com/en/20190601-lebanon-army-chief-angry-budget-measures"target="_blank">France24</a>, <a href = "https://www.bloomberg.com/news/articles/2019-05-27/lebanese-cabinet-backs-2019-budget-with-strong-dose-of-austerity"target="_blank">Bloomberg</a>).
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (6455) Yes
#
# IFP 2305: What will be the disapproval rate for Japan's cabinet in NHK's monthly survey in August 2019?
# Description: This question will be resolved using the disapproval rate reported for the time of interest on <a href = "https://www.nhk.or.jp/bunken/research/yoron/political/2019.html"target="_blank">Nippon Hōsō Kyōkai (NHK)'s website</a>. The cabinet disapproval rate is reported as 支持しない (Do not support) in the first table 内閣：安倍内閣 (Cabinet: Abe Cabinet) on that page. Months are indicated by their corresponding number (e.g. 1月 = January). If NHK conducts more than one survey in a month, question resolution will be based on the first set of results posted. The question will be resolved using <a href = "https://translate.google.com/translate?sl=auto&tl=en&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.nhk.or.jp%2Fbunken%2Fresearch%2Fyoron%2Fpolitical%2F2019.html&edit-text=&act=url"target="_blank">Google Translate</a> services.
# This question will be retroactively closed on the last day the survey was in the field as reported on the NHK <a href = "https://www.nhk.or.jp/bunken/research/yoron/political/2019.html"target="_blank">website</a>. The dates the survey are in the field are reported in the last table on the page under the heading 調査概要.The column containing the dates is labeled 調査時期 (Survey Time) and Months are indicated by their corresponding number followed by the numbered days of the month (e.g. 5月10日(金)～12日(日) = May 10 - 12)
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (6450) Less than 23
#  (6449) Between 23 and 29, inclusive
#  (6448) More than 29 but less than 35
#  (6447) Between 35 and 41, inclusive
#  (6446) More than 41
#
# IFP 2300: What will be the status of the "Violence in the Democratic Republic of Congo" conflict on 7 November 2019 according to the Council on Foreign Relations' Global Conflict Tracker?
# Description: The Council on Foreign Relations (<a href = "https://www.cfr.org/"target="_blank">CFR</a>) monitors issues and conflicts around the world. The CFR's Center for Preventive Action (CPA)'s <a href = "https://www.cfr.org/interactives/global-conflict-tracker#!/global-conflict-tracker"target=_"blank">Global Conflict Tracker</a> provides an overview of conflicts occurring throughout the world. This question will be resolved according to the status of the indicated conflict as listed under the 'Conflict Status' section.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-11-06T19:01:00.000Z
# Options:
#  (6425) Worsening
#  (6424) Unchanging
#  (6423) Improving
#
# IFP 2295: Will the Republic of Cyprus execute or be targeted in a national military attack between 13 June 2019 and 30 July 2019?
# Description: A "national military attack" includes the employment of conventional or unconventional weapons by one country's national military forces (to include special forces) on another country's military, military assets, or territory, including citizens located within that territory, but excluding territorial waters, foreign missions, and/or exclusive economic zones. A "cyber" attack will not qualify as a "national military attack."
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-07-30T18:01:00.000Z
# Options:
#  (6410) Yes
#
# IFP 2290: What will be the unemployment rate for Croatia in August 2019?
# Description: This question will be resolved using data from (<a href = "https://ec.europa.eu/eurostat"target="_blank">Eurostat</a>). To access the relevant data:
# - Go to: <a href="https://ec.europa.eu/eurostat/tgm/table.do?tab=table&init=1&language=en&pcode=teilm020&plugin=1"target="_blank">Eurostat unemployment data</a>;
# -The relevant row is 'Croatia' and the relevant column is '2019M08.'
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (6405) Less than 7.0
#  (6404) Between 7.0 and 7.5, inclusive
#  (6403) More than 7.5
#
# IFP 2285: Will the Government of Canada issue a 'Level 2, 3, or 4' health notice for Mexico between 13 June 2019 and 31 August 2019?
# Description: This question will be resolved using the Canadian government's <a href="https://travel.gc.ca/travelling/health-safety/travel-health-notices"target="blank">Travel health notices</a> for the country of interest. This question will resolve as "yes" if there is a qualifying travel health notice issued where "Date" is in the period of interest.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (6390) Yes
#
# IFP 2280: Between 13 June 2019 and 29 November 2019, will the government of a Gulf Cooperation Council or G7 member formally accuse Iran of a lethal cyberattack?
# Description: Many political analysts suggest Iran could use asymmetric cyberwarfare to retaliate against the various issues confronting them and their relationships with regional neighbors. For the purposes of this question, the attack and accusation must occur during the question's stated time period. Members of GCC and G7 are: <a href = "http://www.gcc-sg.org/en-us/Pages/default.aspx"target="_blank">GCCMemberCountries</a> and <a href = "https://www.cfr.org/backgrounder/g7-and-future-multilateralism"target="_blank">G7MemberCountries</a>. Examples of past accusations, though not lethal cyberattacks, include, but are not limited to: <a href = "https://www.bbc.com/news/uk-41622903"target="_blank">BBC</a> and <a href = "https://www.cnbc.com/2018/02/18/iran-most-dangerous-nation-for-cyber-attacks-says-saudi-foreign-minister.html"target="_blank">CNBC</a>. For the purposes of this question, a lethal cyberattack is one that directly results in at least one fatality.
# Starts: 2019-06-12T16:30:40.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6385) Yes
#
# IFP 2275: Will the Falkland Islands’ referendum to replace the two existing electoral constituencies with a single constituency for the whole of the Islands pass?
# Description: A referendum on reforming the electoral system in the Falkland Islands has been scheduled for 7 November 2019.  Voters will be asked if they want to replace the two existing electoral constituencies, Camp and Stanley, with a single constituency for the whole of the Islands.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-11-06T19:01:00.000Z
# Options:
#  (6380) Yes
#
# IFP 2270: Will ACLED record any civilian fatalities in Tunisia between 7 August 2019 and 7 September 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
# The question will resolve as "yes" if ACLED records any event for which:
# - 'event_type' is "Violence against civilians" or "Explosions/Remote violence" AND;
# - 'actor2' includes "Civilians" AND;
# - 'fatalities' is greater than 0.
# If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-12T16:30:00.000Z, Ends: 2019-09-07T18:01:00.000Z
# Options:
#  (6375) Yes
#
# IFP 2265: Between 6 June 2019 and 29 November 2019, will the Qatari government announce an official ban on the issuance of tourist visas for Egyptians?
#
# Description: A Qatari tourism official recently said the country would not grant visas to Egyptians, though the government subsequently disowned that statement (<a href = "https://www.aljazeera.com/news/2019/05/qatar-denies-issuing-visa-ban-blockading-nations-190506100433022.html"target="_blank">AlJazeera</a>). Egyptians are not eligible for visa-free entry or e-visas (<a href = "https://qatar.vfsevisa.com/Qatar-Online/QROnline/VisaCategoryAndPricingDetails/DisplayVisaCategoryAndPricingDetails"target="_blank">QatarVisa</a>), and some argue the current situation is an unofficial ban (<a href = "https://www.reuters.com/article/us-qatar-politics/qatar-disowns-tourism-officials-comments-on-visas-for-enemies-idUSKCN1SB06O"target="_blank">Reuters</a>).
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6370) Yes
#
# IFP 2260: How many kilograms of cocaine will be seized in England and Wales by police forces and the Border Force during the financial year ending 2019 (April 2018 – March 2019)?
# Description: This question will be resolved using data from UK Home Office's annual "Seizures of drugs in England and Wales" statistical report, typically released in November. To access the relevant data:
# - Go to <a href="https://www.gov.uk/government/collections/seizures-of-drugs-in-england-and-wales" target="_blank">https://www.gov.uk/government/collections/seizures-of-drugs-in-england-and-wales</a>;
# - Click on 'Seizures of drugs in England and Wales, financial year ending 2019';
# - Download the data table for 2019;
# - Within the spreadsheet, use the Table of Contents tab to locate the Summary Table tab that indicates the Quantity of drugs seized by class, drug type and year;
# - Go to that tab;
# - Locate the total quantity of the drug of interest seized by police forces and the Border Force.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (6365) Less than 2,500
#  (6364) Between 2,500 and 3,000, inclusive
#  (6363) More than 3,000 but less than 3,500
#  (6362) Between 3,500 and 4,000, inclusive
#  (6361) More than 4,000
#
# IFP 2255: Between 6 June 2019 and 30 June 2019, will anti-government protests in Albania result in a fatality?
# Description: Anti-government protests in Albania began in mid-February 2019 and have grown in intensity, including the use of firebombs against the office of Prime Minister Edi Rama, who is being accused of corruption and electoral crimes (<a href = "https://www.euronews.com/2019/05/12/albania-protests-continue-as-petrol-bombs-hurled-at-prime-minister-s-office"target="_blank">EuroNews</a>, <a href = "https://www.bbc.com/news/av/world-europe-48241966/albania-protests-petrol-bombs-hurled-at-pm-s-office"target="_blank">BBC</a>, <a href = "https://www.rferl.org/a/albania/29938853.html"target="_blank">RFERL</a>).
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (6340) Yes
#
# IFP 2250: Before 30 July 2019, will Kosovo reduce or revoke the customs tariffs imposed in late 2018 on Serbian and Bosnian goods?
#
# Description: In November and December 2018, Kosovo implemented retaliatory customs tariffs against Serbia and Bosnia-Herzegovina (<a href = "https://www.bbc.com/news/world-europe-46287975"target="_blank">BBC</a>, <a href = "https://www.reuters.com/article/us-kosovo-serbia-tariffs/amid-recognition-row-kosovo-hits-serbia-with-more-customs-tariffs-idUSKCN1OR18Q"target="_blank">Reuters</a>). After six months, the two countries declared they will retaliate against Kosovo if the tariff is not lifted before July 2019 (<a href = "https://www.intellinews.com/bosnia-serbia-warn-of-countermeasures-against-kosovo-if-tariffs-not-removed-by-july-1-161897/?source=serbia"target="_blank">Intellinews</a>, [in Serbian] <a href = "https://www.srbija.gov.rs/vest/386648/srbija-i-bih-za-jaci-pritisak-na-pristinu-da-ukine-takse.php"target="_blank">SerbiaGov</a>). The dispute casts more uncertainty around prospects of Kosovo's EU membership (<a href = "https://prishtinainsight.com/progress-in-kosovo-overshadowed-by-import-tariffs-says-eu-report/"target="_blank">PrishtinaInsight</a>). Reducing or revoking the tariffs by exceptions for particular goods would not count. Temporary suspension, conditional or otherwise, of the tariffs would not count.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (6335) Yes, on Serbian goods only
#  (6334) Yes, on Bosnian goods only
#  (6333) Yes, on both Serbian and Bosnian goods
#  (6332) No
#
# IFP 2245: Will the International Crisis Group report an unchanged, deteriorated, or improved situation for Iran in July 2019?
# Description: The International Crisis Group's monthly bulletin, Crisis Watch, provides short, country-specific updates on political and security developments worldwide, assessing in each case whether the overall situation has deteriorated, improved, or remained unchanged. The question will be resolved according to conflict status for the country of interest for the period of interest as reported within the International Crisis Group’s Crisis Watch Map.  To access the relevant information:
# - Go to <a href = "https://www.crisisgroup.org/crisiswatch"target="_blank">https://www.crisisgroup.org/crisiswatch</a>;
# - Click on 'BROWSE MAP';
# - Click on the country of interest;
# - Hover over the lines at the top of the pop-up window for the status of the period of interest.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-07-31T18:01:00.000Z
# Options:
#  (6315) Unchanged
#  (6314) Deteriorated
#  (6313) Improved
#
# IFP 2240: What will be the closing value of the Philippine peso to one U.S. Dollar exchange rate on 17 July 2019?
# Description: This question will be resolved using the closing value reported by Bloomberg for the date of interest.
# - Go to <a href="https://www.bloomberg.com/quote/USDPHP:CUR"target="_blank">Bloomberg</a>;
# - Click 'VIEW FULL CHART' above the chart on the right;
# - Click the one month time frame '1M'.
# Question will be closed the day before the date of interest.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-07-16T18:01:00.000Z
# Options:
#  (6300) Less than 51.31
#  (6299) Between 51.31 and 51.91, inclusive
#  (6298) More than 51.91 but less than 52.43
#  (6297) Between 52.43 and 53.03, inclusive
#  (6296) More than 53.03
#
# IFP 2235: Before 1 July 2019, will the FAO report 1,200,000 or more pigs have been culled in China to thwart the spread of African Swine Fever?
# Description: China is experiencing an African Swine Fever (ASF) epidemic that has resulted in more than a million pigs being culled. African swine fever is highly contagious and, so far, incurable (<a href="https://www.bbc.com/news/business-47956960"target="_blank">BBC</a>). The Food and Agriculture Organization (FAO) has been publishing weekly reports as the situation unfolds, which include updated statistics on the number of culled swine associated with the viral outbreak that began in August 2018: <a href="http://www.fao.org/ag/againfo/programmes/en/empres/ASF/Situation_update.html"target="_blank">http://www.fao.org/ag/againfo/programmes/en/empres/ASF/Situation_update.html</a>. This question will be resolved by consulting the FAO reports sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, after the question close date. If the indicated threshold is reported to have been exceeded prior to the end date of the question, the question will be resolved retroactively with the date of the update in which the threshold was indicated to have been exceeded as the end date of the question. Previous updates may be accessed using the “ARCHIVE” button in the upper right-hand corner of the FAO ASF situation update page.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (6275) Yes
#
# IFP 2230: Before 30 November 2019, will the European Council decide to open accession negotiations with Albania and/or North Macedonia?
# Description: Both Albania and North Macedonia are candidates for EU membership, and to begin membership negotiations with candidate countries the European Council decision must be unanimous (<a href = "https://ec.europa.eu/neighbourhood-enlargement/policy/steps-towards-joining_en"target="_blank">Europa1</a>). In May 2019, the European Commission recommended opening accession negotiations with both Albania and North Macedonia, but there are still objections from several EU countries (<a href = "https://ec.europa.eu/commission/news/enlargement-package-and-european-elections-2019-may-29_en"target="_blank">Europa2</a>, <a href = "https://www.politico.eu/article/eu-european-union-should-start-membership-talks-with-albania-north-macedonia-commission/"target="_blank">Politico</a>, <a href = "https://www.wsj.com/articles/balkan-leader-warns-of-new-migration-crisis-if-europe-shuts-region-out-11557929901"target="_blank">WSJ</a>, <a href = "https://tsarizm.com/news/balkans/2019/05/20/tsipras-hints-at-possible-different-decisions-on-albania-and-n-macedonia-on-eu-accession-talks/"target="_blank">Tsarizm</a>, <a href = "https://www.france24.com/en/20190528-albanias-riotous-politics-rattle-eu-dreams"target="_blank">France24</a>). A decision to open membership negotiations with the two countries could be made at the European Council's next scheduled meeting on 20-21 June 2019 (<a href = "https://www.consilium.europa.eu/en/meetings/european-council/2019/06/20-21/"target="_blank">ECCalendar</a>). The date accession negotiations would begin and any conditions included with a decision (e.g., <a href = "http://www.mvep.hr/en/croatia-and-the-european-union/negotiation-process/"target="_blank">Croatia</a> in December 2004) are immaterial.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6270) Yes, only Albania
#  (6269) Yes, only North Macedonia
#  (6268) Yes, both Albania and North Macedonia
#  (6267) No
#
# IFP 2225: How many Meetings will the Myanmar Peace Monitor record for August 2019?
# Description: This question will be resolved using the Myanmar Peace Monitor <a href = "http://www.mmpeacemonitor.org/mpm/category/dashboard"target="_blank">monthly dashboard summary</a> for the month of interest. From the dashboard page:
# - Click on the Peace Monitoring Dashboard for the month of interest;
# - Check the number under 'Meetings.'
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-08-31T18:01:00.000Z
# Options:
#  (6250) Less than 4
#  (6249) Between 4 and 6, inclusive
#  (6248) More than 6 but less than 10
#  (6247) Between 10 and 12, inclusive
#  (6246) More than 12
#
# IFP 2220: What will be the number of Dengue Fever cases for Brazil on 6 July 2019 (epidemiological week 27)?
# Description: This question will be resolved using data from the Pan American Health Organization (<a href="http://www.paho.org/data/index.php/en/mnu-topics/indicadores-dengue-en/dengue-nacional-en/252-dengue-pais-ano-en.html"target="_blank">PAHO</a>). To access the relevant data:
# - Go to: <a href="http://www.paho.org/data/index.php/en/mnu-topics/indicadores-dengue-en/dengue-nacional-en/252-dengue-pais-ano-en.html"target="_blank">PAHO</a>;
# - Select the year of interest and the epidemiological week of interest by sliding the bar or clicking the arrows;
# - Scroll down the page to find the country of interest;
# - Total cases is pulled from column b.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting 14 August 2019 and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-07-05T18:01:00.000Z
# Options:
#  (6225) Less than 675,000
#  (6224) Between 675,000 and 720,000, inclusive
#  (6223) More than 720,000 but less than 785,000
#  (6222) Between 785,000 and 850,000, inclusive
#  (6221) More than 850,000
#
# IFP 2215: What will be the average percentage cost of remitting $200 USD from Russia to Ukraine in Third Quarter 2019?
# Description: Remittances are defined here as the transfer of small amounts of money from an individual in one country to an individual in another country. These remittances are often initiated by foreign workers in one country to an individual in their home country. The World Bank provides data on the <a href= "https://remittanceprices.worldbank.org/en" target= "_blank"> costs associated with transferring this money worldwide</a>. To access the relevant data:
# - Go to <a href= "https://remittanceprices.worldbank.org/en/corridor/Russia/Ukraine"target="_blank">https://remittanceprices.worldbank.org/en/corridor/Russia/Ukraine</a>;
# - Above the table, on the right side, set 'Collection period for' to the period of interest;
# - Above the table, on the left side, set currency to 'USD';
# - Click the '200.00 USD' tab;
# - Percentage cost is located in the 'Total cost (%)' column in the 'Total Average' row at the bottom of the table.
# Note that the total average percent cost is the average cost of remitting on the 'Data collected on' date at the top right of the table, not the average for the entire quarter.  This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.  The question will be closed retroactively with the 'Data collected on' date as the end date of the question.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-09-30T18:01:00.000Z
# Options:
#  (6200) Less than 1.3
#  (6199) Between 1.3 and 1.6, inclusive
#  (6198) More than 1.6
#
# IFP 2210: Will Iran execute or be targeted in a national military attack between 6 June 2019 and 5 October 2019?
# Description: A "national military attack" includes the employment of conventional or unconventional weapons by one country's national military forces (to include special forces) on another country's military, military assets, or territory, including citizens located within that territory, but excluding territorial waters, foreign missions, and/or exclusive economic zones. A "cyber" attack will not qualify as a "national military attack."
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-10-05T18:01:00.000Z
# Options:
#  (6185) Yes
#
# IFP 2205: According to the Council on Foreign Relations (CFR) Global Monetary Policy Tracker, what will be the global monetary policy index in October 2019?
# Description: The Council on Foreign Relations (CFR) Global Monetary Policy Tracker compiles data from 54 countries around the world to highlight significant global trends in monetary policy. To access the relevant data:
# - Go to <a href = "https://www.cfr.org/global/global-monetary-policy-tracker/p37726"target="_blank"> Council of Foreign Relations' Global Monetary Policy Tracker</a>;
# - Select the period of interest in the 'As of:' field above the 'Index of Global Easing (-) / Tightening (+)*' color bar;
# - Hover the cursor over the black dot on the color bar to read the policy index.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (6176) Less than -1.0
#  (6180) Between -1.0 and 1.0, inclusive
#  (6179) More than 1.0 but less than 2.0
#  (6178) Between 2.0 and 3.0, inclusive
#  (6177) More than 3.0
#
# IFP 2200: Will the UN Security Council adopt a resolution concerning Yemen between 9 June 2019 and 8 October 2019?
# Description: This question will resolve as "yes" if the United Nations Security Council (UNSC) adopts a resolution during the period of interest in which the country/region of interest appears in the short description in the <a href="https://www.un.org/securitycouncil/content/resolutions-adopted-security-council-2019"target="_blank">Security Council Resolution table </a> and/or is mentioned within the adopted resolution itself.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-10-08T18:01:00.000Z
# Options:
#  (6155) Yes
#
# IFP 2195: Before 30 November, will the UK's MI5 change their international terrorism threat level from SEVERE?
# Description: This question will be resolved based on MI5's reporting of the 'Current threat from international terrorism' heading found at <a href = "https://www.mi5.gov.uk/threat-levels"target="_blank">https://www.mi5.gov.uk/threat-levels</a>. The question will be resolved retroactively if the threat level changes prior to the close date.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6150) Yes
#
# IFP 2190: Will there be a significant day-over-day increase in worldwide search interest in the term "sabotage" reported by Google Trends between 1 July 2019 and 31 July 2019?
# Description: Google Trends tracks how often a particular search-term is entered relative to the total search-volume. Values represent search interest relative to the highest value for the given region and period of interest. A value of 100 is the peak popularity for the term during the period of interest. A value of 50 means that the term is half as popular. A score of 0 means there was not enough data for this term. This question will resolve as 'yes' if Google Trends shows a 50-point or greater increase of interest in the search term in one (1) day during the period of interest. To access the relevant data, from <a href="https://trends.google.com/trends/explore"target="_blank">Google Trends</a>:
# - Enter the search term of interest (as a 'Search term' not a 'Topic');
# - Make sure 'Worldwide' is selected for the geographic area;
# - Use the drop-down field to enter a 'Custom time range' corresponding to the period of interest;
# - Click the down arrow in the top right of the 'Interest over time' chart to download the data to a CSV file.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-07-31T18:01:00.000Z
# Options:
#  (6145) Yes
#
# IFP 2185: Will Indonesia's President Joko Widodo experience a significant leadership disruption between 6 June 2019 and 31 October 2019?
# Description: A "significant leadership disruption" includes confirmed reports that the leader has:
# - resigned (including the issuance of a resignation that will take effect at a later date),
# - lost a confidence vote,
# - formally left office,
# - died,
# - been forcibly removed from office for 10 or more consecutive days,
# - fled or been exiled from office for 10 or more consecutive days,
# - been medically incapacitated or hospitalized for 10 or more consecutive days,
# - been missing (whereabouts unknown) for 10 or more consecutive days.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (6140) Yes
#
# IFP 2180: Which country will have the most energy-efficient supercomputers in the top 10 of the November 2019 Green500 list of highest-performing computer systems?
# Description: The <a href ="https://www.top500.org/green500/"target="_blank">Green500 list</a> ranks the top 500 highest-performing computing systems by energy efficiency. The Green500 list is published twice per year, generally in June and November. The question will be resolved according to the data associated with the November 2019 Green500 list. To access the data, visit <a href ="https://www.top500.org/green500/lists/"target="_blank"> https://www.top500.org/green500/lists/</a>:
# - Select 'November 2019' from the 'LISTS' drop down menu.
# - Refer to the Green500 List for November 2019.
# Question will be resolved according to the data presented in the list.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (6135) Japan
#  (6134) United States
#  (6133) Japan and United States (tie)
#  (6132) Some other outcome
#
# IFP 2175: What will be the number of Dengue Fever cases for Mexico on 6 July 2019 (epidemiological week 27)?
# Description: This question will be resolved using data from the Pan American Health Organization (<a href="http://www.paho.org/data/index.php/en/mnu-topics/indicadores-dengue-en/dengue-nacional-en/252-dengue-pais-ano-en.html"target="_blank">PAHO</a>). To access the relevant data:
# - Go to: <a href="http://www.paho.org/data/index.php/en/mnu-topics/indicadores-dengue-en/dengue-nacional-en/252-dengue-pais-ano-en.html"target="_blank">PAHO</a>;
# - Select the year of interest and the epidemiological week of interest by sliding the bar or clicking the arrows;
# - Scroll down the page to find the country of interest;
# - Total cases is pulled from column b.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting 14 August 2019 and continuing once each week until the data are successfully retrieved.
# Starts: 2019-06-05T16:30:00.000Z, Ends: 2019-07-05T18:01:00.000Z
# Options:
#  (6115) Less than 16,000
#  (6114) Between 16,000 and 18,000, inclusive
#  (6113) More than 18,000 but less than 21,000
#  (6112) Between 21,000 and 23,000, inclusive
#  (6111) More than 23,000
#
# IFP 2170: Will ACLED record any riots in South Sudan between 1 November 2019 and 30 November 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
# The question will resolve as "yes" if ACLED records any event for which 'event_type' is Riots. If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-29T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6090) Yes
#
# IFP 2160: Between 30 May 2019 and 29 November 2019, will an Ebola health worker be injured or killed in an attack against an Ebola facility inside the Central African Republic, South Sudan, Uganda, Rwanda, Burundi, or Tanzania?
# Description: Frequent and sometimes even deadly attacks against the Ebola response efforts in the Democratic Republic of the Congo (DRC) threaten successful containment of the disease to DRC's borders (<a href = "https://www.economist.com/middle-east-and-africa/2019/04/28/the-ebola-outbreak-in-congo-is-getting-worse"target="_blank">Economist</a>, <a href = "https://www.aljazeera.com/news/2019/05/warns-ebola-breach-drc-borders-attacks-stop-190510185356288.html"target="_blank">AlJazeera</a>, <a href = "https://www.vox.com/2019/3/1/18245905/ebola-outbreak-congo"target="_blank">Vox</a>, <a href = "https://www.france24.com/en/20190524-high-security-ebola-burials-spark-dismay-anger-dr-congo"target="_blank">France24</a>). Some high risk countries bordering DRC, for example Uganda, have instituted preparedness responses (<a href = "https://afro.who.int/news/uganda-steps-ebola-preparedness-response-22-high-risk-districts"target="_blank">WHO</a>).
# Starts: 2019-05-29T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (6080) Yes
#
# IFP 2155: How many of Ukraine's Central Election Commission (CEC) members will cease to be a member by 29 July 2019?
# Description: As of question launch, there are sixteen members of Ukraine's CEC:
# Tetiana SLIPACHUK, Oleh KONOPOLSKYI, Yevhenii RADCHENKO, Nataliia BERNATSKA, Alla BASALAIEVA, Mykhailo VERBENSKYI, Oleh DIDENKO, Andrii YEVSTIHNIEIEV, Iryna YEFREMOVA, Olga ZHELTOVA, Svitlana KUSTOVA, Olga LOTIUK, Kateryna MAKHNITSKA, Vitalii PLUKAR, Leontii SHYPILOV, and Tetiana YUZKOVA (in Ukrainian: <a href = "https://www.cvk.gov.ua/skladcec/"target="_blank">UkraineGov</a>). Ukraine's CEC was overhauled towards the end of 2018 (<a href = "https://www.kyivpost.com/ukraine-politics/after-four-years-parliament-appoints-new-members-to-central-election-commission.html"target="_blank">KyivPost</a>) and will oversee the upcoming snap parliamentary elections (<a href = "https://www.bbc.com/news/world-europe-48330955"target="_blank">BBC</a>, <a href = "https://www.usip.org/publications/2019/02/preventing-violence-during-ukraines-2019-elections"target="_blank">USIP</a>). If the 17th CEC position (vacant at time of question launch) is filled during the question period, and that individual subsequently ceases to be a member, it will count towards resolution.
# Starts: 2019-05-29T16:30:00.000Z, Ends: 2019-07-29T18:01:00.000Z
# Options:
#  (6072) 0
#  (6073) Between 1 and 4, inclusive
#  (6075) Between 5 and 8, inclusive
#  (6074) More than 8
#
# IFP 2150: How many patents will China publish that have International Patent Classification (IPC) code 'G06N' (COMPUTER SYSTEMS BASED ON SPECIFIC COMPUTATIONAL MODELS) in June 2019?
# Description: This question will be resolved using data from the European Patent Office. To access the relevant data:
# - Go to <a href="https://worldwide.espacenet.com/"target="_blank">Espacenet</a>;
# - Click on 'Advanced search' on the left of the page;
# - Verify that 'Worldwide – collection of published applications from 100+ countries' is selected in the collection search drop-down at the top;
# - Enter 'CN' in the 'Publication number' field;
# - Enter the year and month of interest in YYYYMM format in the 'Publication date' field;
# - Enter the IPC code of interest in the 'IPC' field;
# - Click 'Search.'
# The number of patents published is shown at the top of the 'Result list.'  If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-29T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (6055) Less than 1,000
#  (6054) Between 1,000 and 1,500, inclusive
#  (6053) More than 1,500
#
# IFP 2145: How many 'hacking or malware (HACK)' data breaches will Privacy Rights Clearinghouse record in June 2019?
# Description: This question will be resolved using <a href = "https://www.privacyrights.org/data-breaches"target="_blank">Privacy Rights Clearinghouse's Chronology of Data Breaches</a>. To access the relevant data:
# - Select 'Hacking or Malware (HACK)' as the type of breach;
# - Click 'Search Data Breaches';
# - Download the 'Data Breach File';
# - Count the number of entries, for all organizations, in which 'Date Made Public' falls in the month of interest (sort by 'Date Made Public', if necessary). If the count crosses the highest answer bin threshold before the close date, the question will be closed retroactively with the crossing date as the end date of the question. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting 31 July 2019 and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-29T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (6040) Less than 10
#  (6039) Between 10 and 16, inclusive
#  (6038) More than 16 but less than 22
#  (6037) Between 22 and 30, inclusive
#  (6036) More than 30
#
# ...
# Starts: 2019-05-22T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (5716) Less than 49
#  (5720) Between 49 and 54, inclusive
#  (5719) More than 54 but less than 58
#  (5718) Between 58 and 62, inclusive
#  (5717) More than 62
#
# IFP 2020: What will be the daily closing price of platinum on 25 June 2019 in USD?
# Description: This question will be resolved using the last daily London Bullion Market Association (LBMA) Platinum Price USD (PM) <a href="http://www.lbma.org.uk/precious-metal-prices"target="_blank">http://www.lbma.org.uk/precious-metal-prices</a> for the date of interest. To access the relevant data:
# - Select 'Table';
# - Select 'Platinum' from the 'Price for' dropdown menu;
# - Refer to the 'PM' column under 'USD.'
# This question will be closed on the day before the date of interest.
# Starts: 2019-05-22T16:30:00.000Z, Ends: 2019-06-24T18:01:00.000Z
# Options:
#  (5693) Less than $790
#  (5695) Between $790 and $830, inclusive
#  (5691) More than $830 but less than $870
#  (5692) Between $870 and $920, inclusive
#  (5694) More than $920
#
# IFP 2015: How much crude oil will Iraq produce in October 2019?
# Description: This question will be resolved using oil production data measured in thousands of barrels per day (tb/d) reported for the country of interest for the month of interest in the "OPEC crude oil production based on secondary sources" table of the OPEC Monthly Oil Market Report (<a href="http://www.opec.org/opec_web/en/publications/338.htm"target="_blank">http://www.opec.org/opec_web/en/publications/338.htm</a>), expected to be published the first part of the following month. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-22T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (5670) Less than 4,394
#  (5669) Between 4,394 and 4,484, inclusive
#  (5666) More than 4,484 but less than 4,560
#  (5668) Between 4,560 and 4,650, inclusive
#  (5667) More than 4,650
#
# IFP 2005: How many homicides will the Mexican government report for Guerrero in June 2019?
# Description: This question will be resolved using data reported by The Executive Secretariat of the National Public Security System of the Mexican government. To download the relevant data:
# - Go to <a href="https://www.gob.mx/sesnsp/acciones-y-programas/victimas-nueva-metodologia?state=published"target="_blank">National Public Security System</a>;
# - Download the spreadsheet under 'Reportes de víctimas por año (formato PDF)', entitled 'Victimas 2019';
# - The number of homicides are reported in the table for the State of interest (the name of the Mexican state can be found under "Victimas de delitos del fuero común") in row 1.1 ('Homicidio') for the month of interest.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-22T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (5620) Less than 211
#  (5619) Between 211 and 231, inclusive
#  (5618) More than 231 but less than 246
#  (5617) Between 246 and 265, inclusive
#  (5616) More than 265
#
# IFP 2000: Will ACLED record any riots in Vietnam between 21 June 2019 and 21 July 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
# The question will resolve as "yes" if ACLED records any event for which 'event_type' is Riots. If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-21T18:01:00.000Z
# Options:
#  (5595) Yes
#
# IFP 1995: Which country will account for the largest performance share in computational power in the November 2019 TOP500 list of highest-performing computer systems?
# Description: The <a href = "https://www.top500.org/lists/"target="_blank">TOP500 list of the highest-performing computing systems</a> is published twice per year, generally in June and November. Question will be resolved according to the data associated with the November 2019 TOP500 list. To access the data, visit  <a href = "https://www.top500.org/statistics/list/"target="_blank">https://www.top500.org/statistics/list/</a>:
# - Select 'November 2019' from the 'TOP500 Release' drop down menu;
# - Select 'Countries' in the 'Category' drop down menu.
# - Click 'Submit.'
# Question will be resolved according to the data illustrated in the 'Countries Performance Share' pie chart.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-10-31T18:01:00.000Z
# Options:
#  (5590) China
#  (5589) United States
#  (5588) All other countries combined
#
# IFP 1985: On 29 July 2019, how many total cases of polio will be reported by EndPolio in Pakistan for 2019?
# Description: Polio has been eradicated in almost all countries with a few exceptions, including Pakistan (<a href = "http://www.endpolio.com.pk/polioin-pakistan/polio-cases-in-provinces"target="_blank">EndPolio</a>, <a href = "https://www.nytimes.com/2019/04/25/world/asia/polio-vaccine-pakistan.html"target="_blank">NYT</a>). In 2018, EndPolio reported 12 total polio cases.  As of 15 May 2019, there were 15 total polio cases so far in 2019 for Pakistan. This question will be resolved by consulting the End Polio data between 12:00 PM and 2:00 PM ET on 29 July 2019. Resolution will be based on the value observed at the time of source consultation.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-28T18:01:00.000Z
# Options:
#  (5553) Less than 20
#  (5554) Between 20 and 29, inclusive
#  (5552) More than 29 but less than 40
#  (5551) Between 40 and 49, inclusive
#  (5555) More than 49
#
# IFP 1975: Between 16 May 2019 and 30 July 2019, for two consecutive Saturdays, will fewer than 5,000 cumulative daily protesters participate in "Yellow Vests" protests across France?
# Description: What began in November 2018 as protests against fuel tax hikes have grown into an ongoing series of protests across France, particularly on Saturdays (<a href = "https://www.bloomberg.com/news/articles/2019-04-30/why-yellow-vests-remain-thorn-in-macron-presidency-quicktake"target="_blank">Bloomberg</a>, <a href = "https://www.france24.com/en/20181127-france-yellow-vest-protest-movement-macron-fuel-tax"target="_blank">France24(1)</a>). President Macron has offered concessions over several months, but the protests continue (<a href = "https://www.france24.com/en/20190427-france-yellow-vest-macron-great-national-debate-act-24-tax-protest"target="_blank">France24(2)</a>, <a href = "https://www.wsj.com/articles/frances-yellow-vests-are-unappeased-and-back-to-demanding-change-11556385648"target="_blank">WSJ</a>).
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-30T18:01:00.000Z
# Options:
#  (5525) Yes
#
# IFP 1965: Will Julian Assange leave the UK between 16 May 2019 and 15 July 2019?
# Description: Julian Assange was arrested on 11 April 2019 in the UK (<a href = "https://www.nytimes.com/2019/04/11/world/europe/julian-assange-wikileaks-ecuador-embassy.html"target="_blank">New York Times</a>).
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-15T18:01:00.000Z
# Options:
#  (5495) Yes
#
# IFP 1960: Will there be a significant day-over-day increase in worldwide search interest in the term "ISIS" reported by Google Trends between 1 November 2019 and 29 November 2019?
# Description: Google Trends tracks how often a particular search-term is entered relative to the total search-volume. Values represent search interest relative to the highest value for the given region and period of interest. A value of 100 is the peak popularity for the term during the period of interest. A value of 50 means that the term is half as popular. A score of 0 means there was not enough data for this term. This question will resolve as 'yes' if Google Trends shows a 50-point or greater increase of interest in the search term in one (1) day during the period of interest. To access the relevant data, from <a href= "https://trends.google.com/trends/explore"target="_blank">Google Trends</a>:
# - Enter the search term of interest (as a 'Search term' not a 'Topic');
# - Make sure 'Worldwide' is selected for the geographic area;
# - Use the drop-down field to enter a 'Custom time range' corresponding to the period of interest;
# - Click the down arrow in the top right of the 'Interest over time' chart to download the data to a CSV file.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-11-29T19:01:00.000Z
# Options:
#  (5490) Yes
#
# IFP 1955: What will be the price of casual labor (unskilled, daily, without food) in Somalia in the Elwak market for June 2019?
# Description: The Famine Early Warning Systems Network (FEWS NET) provides early warning and analysis on acute food insecurity around the world. The question will be resolved using data downloaded from FEWS NET at: <a href="http://fews.net/content/staple-food-price-data-1995-present" target="_blank">http://fews.net/content/staple-food-price-data-1995-present</a>. The relevant price can be found where 'country' is the country of interest; 'market' is the market of interest; 'product' is the product of interest; 'period_date' is the date of interest; and 'value' is the price. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (5485) Less than 102,600
#  (5484) Between 102,600 and 109,500, inclusive
#  (5483) More than 109,500 but less than 115,500
#  (5482) Between 115,500 and 122,400, inclusive
#  (5481) More than 122,400
#
# IFP 1950: How many Total Registered Syrian Refugees will be reported by the UNHCR on 15 July 2019?
# Description: This question will be resolved using data from the <a href = "http://popstats.unhcr.org/en/overview"target="_blank">United Nations High Commissioner for Refugees </a>(UNHCR). The outcome will be determined by the reported number of Total Registered Syrian Refugees on the date of interest according to the UNHCR's <a href = "https://data2.unhcr.org/en/situations/syria"target="_blank">Syria Regional Refugee Response</a> website.  This question will be resolved by consulting the data source between 12:00 PM ET and 2:00 PM ET on the date of interest.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-14T18:01:00.000Z
# Options:
#  (5456) Less than 5,160,000
#  (5458) Between 5,160,000 and 5,430,000, inclusive
#  (5457) More than 5,430,000 but less than 5,670,000
#  (5459) Between 5,670,000 and 5,900,000, inclusive
#  (5460) More than 5,900,000
#
# IFP 1945: Will Sudan execute or be targeted in a national military attack between 16 May 2019 and 30 June 2019?
# Description: A "national military attack" includes the employment of conventional or unconventional weapons by one country's national military forces (to include special forces) on another country's military, military assets, or territory, including citizens located within that territory, but excluding territorial waters, foreign missions, and/or exclusive economic zones. A "cyber" attack will not qualify as a "national military attack."
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-06-30T18:01:00.000Z
# Options:
#  (5435) Yes
#
# IFP 1940: What will be the daily closing price of gold on 10 July 2019 in USD?
# Description: This question will be resolved using the last daily London Bullion Market Association (LBMA) Gold Price USD (PM) <a href="http://www.lbma.org.uk/precious-metal-prices"target="_blank">http://www.lbma.org.uk/precious-metal-prices</a> for the date of interest. To access the relevant data:
# - Select 'Table';
# - Refer to the 'PM' column under 'USD.'
# Question will be closed on the day before the date of interest.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-09T18:01:00.000Z
# Options:
#  (5430) Less than $1,160
#  (5429) Between $1,160 and $1,250, inclusive
#  (5428) More than $1,250 but less than $1,320
#  (5427) Between $1,320 and $1,400, inclusive
#  (5426) More than $1,400
#
# IFP 1935: Will ACLED record any riots in Thailand between 7 June 2019 and 7 July 2019?
# Description: The Armed Conflict Location and Event Dataset (ACLED) summarizes press reports on conflict and protest events in Africa and parts of Asia. The relevant data can be accessed using the export tool at <a href = "https://www.acleddata.com/data/"target="_blank">https://www.acleddata.com/data/</a>:
# - Set 'From' to the first day of the period of interest;
# - Set 'To' to the last day of the period of interest;
# - Set 'Country' to the country of interest;
# - Click 'Export.'
# The question will resolve as "yes" if ACLED records any event for which 'event_type' is Riots. If a qualifying event is recorded, the question will be closed retroactively with the date of the first event as the end date of the question.
# This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-07-07T18:01:00.000Z
# Options:
#  (5405) Yes
#
# IFP 1930: Will the PITF Worldwide Atrocities Dataset record an event perpetrated by a state actor in Brazil (BRA) that starts between 18 August 2019 and 18 September 2019?
# Description: This question will resolve as "yes" if the Political Instability Task Force (<a href = "http://eventdata.parusanalytics.com/data.dir/atrocities.html"target="_blank">PITF</a>) Worldwide Atrocities Dataset records any event with a start date (Start Day, Start Month, Start Year) in the period of interest, inclusive, for which 'Event Location: Country' is the country of interest, and 'Perpetrators: Perp State Role' is: 'State Perpetrator'; 'Transnational, State'; 'Multiple Perpetrators (State)'; or 'Multiple Perpetrators (State and Non-State)'. This question will be resolved by consulting the data source once each week sometime between 10:00 AM ET Wednesday and 4:00 PM ET Thursday, starting the Wednesday after the question close date and continuing once each week until the data are successfully retrieved.
# Starts: 2019-05-15T16:30:00.000Z, Ends: 2019-09-18T18:01:00.000Z
# Options:
#  (5400) Yes

# %%
pprint(sorted([(i["id"], i["name"]) for i in ifps]))
# Out:
# [(1930,
#   'Will the PITF Worldwide Atrocities Dataset record an event perpetrated by a '
#   'state actor in Brazil (BRA) that starts between 18 August 2019 and 18 '
#   'September 2019?'),
#  (1935,
#   'Will ACLED record any riots in Thailand between 7 June 2019 and 7 July '
#   '2019?'),
#  (1940, 'What will be the daily closing price of gold on 10 July 2019 in USD?'),
#  (1945,
#   'Will Sudan execute or be targeted in a national military attack between 16 '
#   'May 2019 and 30 June 2019?'),
#  (1950,
#   'How many Total Registered Syrian Refugees will be reported by the UNHCR on '
#   '15 July 2019?'),
#  (1955,
#   'What will be the price of casual labor (unskilled, daily, without food) in '
#   'Somalia in the Elwak market for June 2019?'),
#  (1960,
#   'Will there be a significant day-over-day increase in worldwide search '
#   'interest in the term "ISIS" reported by Google Trends between 1 November '
#   '2019 and 29 November 2019?'),
#  (1965,
#   'Will Julian Assange leave the UK between 16 May 2019 and 15 July 2019?'),
#  (1975,
#   'Between 16 May 2019 and 30 July 2019, for two consecutive Saturdays, will '
#   'fewer than 5,000 cumulative daily protesters participate in "Yellow Vests" '
#   'protests across France?'),
#  (1985,
#   'On 29 July 2019, how many total cases of polio will be reported by EndPolio '
#   'in Pakistan for 2019? '),
#  (1995,
#   'Which country will account for the largest performance share in '
#   'computational power in the November 2019 TOP500 list of highest-performing '
#   'computer systems?'),
#  (2000,
#   'Will ACLED record any riots in Vietnam between 21 June 2019 and 21 July '
#   '2019?\xa0'),
#  (2005,
#   'How many homicides will the Mexican government report for Guerrero in June '
#   '2019?'),
#  (2015, 'How much crude oil will Iraq produce in October 2019?'),
#  (2020,
#   'What will be the daily closing price of platinum on 25 June 2019 in USD?'),
#  (2025,
#   "What percentage of respondents will say that Germany's federal government "
#   "is working well ('gut') in the June 2019 Politbarometer survey? "),
#  (2030,
#   'Will there be an earthquake of magnitude 8.5 or stronger worldwide between '
#   '23 May 2019 and 31 October 2019?'),
#  (2040,
#   "Will South Sudan's President Salva Kiir Mayardit experience a significant "
#   'leadership disruption between 23 May 2019 and 15 July 2019? '),
#  (2045,
#   'Will the United Kingdom (UK) leave the European Union (EU) before 1 '
#   'November 2019?'),
#  (2050,
#   'Between 23 May 2019 and 30 July 2019, will the Spanish monarch appoint a '
#   'President of the Government?'),
#  (2055,
#   'How many civilians will be killed in Syria in September 2019, according to '
#   'the Syrian Network for Human Rights (SNHR)?'),
#  (2060,
#   'Will FEWS NET publish an alert for Afghanistan between 23 May 2019 and 25 '
#   'September 2019?'),
#  (2065,
#   'Will the Government of Canada issue a travel advisory of "Avoid '
#   'non-essential travel" or "Avoid all travel" for China between 23 May 2019 '
#   'and 21 August 2019?'),
#  (2070,
#   "Before 30 November 2019, will Germany's Bundestag adopt a bill that would "
#   'impose a fine on parents who refuse a measles vaccine for their children?'),
#  (2075, 'How many battle deaths will ACLED record in India in June 2019?'),
#  (2080,
#   'Between 23 May 2019 and 29 November 2019, how many formal UN-sponsored '
#   'talks will be convened between Morocco and the Polisario Front to address '
#   'the Western Sahara conflict?\r\n'),
#  (2085,
#   'Between 23 May 2019 and 29 November 2019, how many tranches will the IMF '
#   'approve for release to Ukraine?'),
#  (2090,
#   'How many incidents of piracy and armed robbery will the IMO record in '
#   'international or territorial waters in the South China Sea between 24 June '
#   '2019 and 24 July 2019?\xa0'),
#  (2095,
#   'How many cases of measles will the European Centre for Disease Prevention '
#   'and Control record in Poland for July 2019?'),
#  (2100,
#   'Will there be more than 3,500 cumulative Ebola cases from the North Kivu '
#   'Ebola Outbreak before 1 October 2019, according to the Humanitarian Data '
#   'Exchange?'),
#  (2105,
#   'Between 30 May 2019 and 1 November 2019, will United Kingdom or Republic of '
#   'Ireland authorities attribute three or more deaths to Irish '
#   'republican/nationalist or unionist/loyalist violence?'),
#  (2110,
#   'Will a nuclear or radiological event occur with an INES Level 3 or higher '
#   'rating between 30 May 2019 and 31 August 2019?'),
#  (2115, "Who will win Istanbul, Turkey's mayoral election?"),
#  (2120,
#   'What will be the long-term interest rate for Hungary (HUN) in July 2019?'),
#  (2125,
#   'How many terrorist incidents with 15 or more dead (victims + perpetrators) '
#   'will occur between 1 July 2019 and 31 July 2019 as reported by Wikipedia?'),
#  (2130,
#   'How many strikes and worker protests will China Labour Bulletin record as '
#   'having occurred between 28 July 2019 and 28 August 2019?'),
#  (2135,
#   'Will Iran close the Strait of Hormuz for any length of time between 30 May '
#   '2019 and 20 July 2019?'),
#  (2140,
#   'How many deaths perpetrated by Boko Haram will the Council on Foreign '
#   'Relations report for June 2019?'),
#  (2145,
#   "How many 'hacking or malware (HACK)' data breaches will Privacy Rights "
#   'Clearinghouse record in June 2019?'),
#  (2150,
#   'How many patents will China publish that have International Patent '
#   "Classification (IPC) code 'G06N' (COMPUTER SYSTEMS BASED ON SPECIFIC "
#   'COMPUTATIONAL MODELS) in June 2019?'),
#  (2155,
#   "How many of Ukraine's Central Election Commission (CEC) members will cease "
#   'to be a member by 29 July 2019?'),
#  (2160,
#   'Between 30 May 2019 and 29 November 2019, will an Ebola health worker be '
#   'injured or killed in an attack against an Ebola facility inside the Central '
#   'African Republic, South Sudan, Uganda, Rwanda, Burundi, or Tanzania?'),
#  (2170,
#   'Will ACLED record any riots in South Sudan between 1 November 2019 and 30 '
#   'November 2019?'),
#  (2175,
#   'What will be the number of Dengue Fever cases for Mexico on 6 July 2019 '
#   '(epidemiological week 27)?'),
#  (2180,
#   'Which country will have the most energy-efficient supercomputers in the top '
#   '10 of the November 2019 Green500 list of highest-performing computer '
#   'systems?'),
#  (2185,
#   "Will Indonesia's President Joko Widodo experience a significant leadership "
#   'disruption between 6 June 2019 and 31 October 2019?'),
#  (2190,
#   'Will there be a significant day-over-day increase in worldwide search '
#   'interest in the term "sabotage" reported by Google Trends between 1 July '
#   '2019 and 31 July 2019?'),
#  (2195,
#   "Before 30 November, will the UK's MI5 change their international terrorism "
#   'threat level from SEVERE?'),
#  (2200,
#   'Will the UN Security Council adopt a resolution concerning Yemen between 9 '
#   'June 2019 and 8 October 2019?'),
#  (2205,
#   'According to the Council on Foreign Relations (CFR) Global Monetary Policy '
#   'Tracker, what will be the global monetary policy index in October 2019?'),
#  (2210,
#   'Will Iran execute or be targeted in a national military attack between 6 '
#   'June 2019 and 5 October 2019?'),
#  (2215,
#   'What will be the average percentage cost of remitting $200 USD from Russia '
#   'to Ukraine in Third Quarter 2019?'),
#  (2220,
#   'What will be the number of Dengue Fever cases for Brazil on 6 July 2019 '
#   '(epidemiological week 27)?'),
#  (2225,
#   'How many Meetings will the Myanmar Peace Monitor record for August 2019?'),
#  (2230,
#   'Before 30 November 2019, will the European Council decide to open accession '
#   'negotiations with Albania and/or North Macedonia?'),
#  (2235,
#   'Before 1 July 2019, will the FAO report 1,200,000 or more pigs have been '
#   'culled in China to thwart the spread of African Swine Fever?'),
#  (2240,
#   'What will be the closing value of the Philippine peso to one U.S. Dollar '
#   'exchange rate on 17 July 2019?'),
#  (2245,
#   'Will the International Crisis Group report an unchanged, deteriorated, or '
#   'improved situation for Iran in July 2019?'),
#  (2250,
#   'Before 30 July 2019, will Kosovo reduce or revoke the customs tariffs '
#   'imposed in late 2018 on Serbian and Bosnian goods?\r\n'),
#  (2255,
#   'Between 6 June 2019 and 30 June 2019, will anti-government protests in '
#   'Albania result in a fatality?'),
#  (2260,
#   'How many kilograms of cocaine will be seized in England and Wales by police '
#   'forces and the Border Force during the financial year ending 2019 (April '
#   '2018 – March 2019)?'),
#  (2265,
#   'Between 6 June 2019 and 29 November 2019, will the Qatari government '
#   'announce an official ban on the issuance of tourist visas for '
#   'Egyptians?\r\n'),
#  (2270,
#   'Will ACLED record any civilian fatalities in Tunisia between 7 August 2019 '
#   'and 7 September 2019?'),
#  (2275,
#   'Will the Falkland Islands’ referendum to replace the two existing electoral '
#   'constituencies with a single constituency for the whole of the Islands '
#   'pass? '),
#  (2280,
#   'Between 13 June 2019 and 29 November 2019, will the government of a Gulf '
#   'Cooperation Council or G7 member formally accuse Iran of a lethal '
#   'cyberattack?'),
#  (2285,
#   "Will the Government of Canada issue a 'Level 2, 3, or 4' health notice for "
#   'Mexico between 13 June 2019 and 31 August 2019? '),
#  (2290, 'What will be the unemployment rate for Croatia in August 2019?'),
#  (2295,
#   'Will the Republic of Cyprus execute or be targeted in a national military '
#   'attack between 13 June 2019 and 30 July 2019?'),
#  (2300,
#   'What will be the status of the "Violence in the Democratic Republic of '
#   'Congo" conflict on 7 November 2019 according to the Council on Foreign '
#   "Relations' Global Conflict Tracker?"),
#  (2305,
#   "What will be the disapproval rate for Japan's cabinet in NHK's monthly "
#   'survey in August 2019?'),
#  (2310,
#   'Between 13 June 2019 and 29 July 2019, will budget protests in Lebanon '
#   'result in a fatality?'),
#  (2315,
#   "Before 1 July 2019, will the European Commission (EC) extend Switzerland's "
#   'stock market equivalence status?'),
#  (2320,
#   "Will Ukraine's President Volodymyr Zelensky experience a significant "
#   'leadership disruption between 13 June 2019 and 29 November 2019?'),
#  (2325,
#   'Will the Aviation Safety Network record a hijacking or criminal occurrence '
#   'between 22 June 2019 and 22 July 2019?'),
#  (2330,
#   'Will the Basel Institute of Governance indicate that Saudi Arabia has a '
#   'lower, unchanged, or higher risk of money laundering / terrorist financing '
#   'in 2019 compared to 2018?\xa0'),
#  (2335,
#   'What will be the monthly period-over-period change in the consumer price '
#   'index (CPI) for China, P.R.: Mainland in June 2019?'),
#  (2340,
#   'Will the European Union file a\xa0World Trade Organization\xa0dispute '
#   'against any country/territory between 13 June 2019 and 29 November 2019?'),
#  (2345,
#   "Will Iran's President Hassan Rouhani experience a significant leadership "
#   'disruption between 13 June 2019 and 5 October 2019?'),
#  (2350, 'Who will be Prime Minister of the United Kingdom on 30 July 2019?'),
#  (2355,
#   'Will there be a 10% decrease in the daily closing price of the EURONEXT '
#   'N100 over any interval of five or fewer business days between 13 June 2019 '
#   'and 29 November 2019?')]

# %%
pprint([i for i in ifps if not i["active?"]][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-5e5332b02f9a> in <module>()
# ----> 1 pprint([i for i in ifps if not i["active?"]][1])
#
# IndexError: list index out of range

# %% [markdown]
# We can retrieve human forecasts. If we'd like, we can limit them to a particular `question_id`, and can constrain the creation or update dates. In this notebook we will set the `training_data` flag to `True` to ensure that there are human forecasts to retrieve from the staging platform.  To limit the response we will only look at the last portion of the training data by passing a value for `created_after`

# %%
preds=gf.get_human_forecasts(training_data=False, created_after=datetime.datetime(2019,5,16,0,0,0))
if 'errors' in preds:
    print("We ran into a problem:")
    print(preds)
else:
    print("Retrieved {} human forecasts".format(len(preds)))

# %%
q_id = 1930
q_preds = [p for p in preds if p["question_id"] == q_id]
print(len(q_preds))

# %%
from collections import Counter
Counter([p["question_id"] for p in preds])

# %% [markdown]
# Let's look at an item in the human forecast stream. The `question_id` links us to the `get_questions()` results. The `membership_guid` is the unique identifier for a human forecaster, and will remain consistent throughout the Challenge.
#
# Each item in the `predictions` list includes the `answer_id` for that alternative, which aligns to the `get_questions()` output, and a `forecasted_probability` which indicates the human forecaster's submitted probability for that alternative.
#
# Here is an example prediction from the training data available on the staging platform.  Examining the elements of the forecast:
#
# - `created_at`: the timestamp of the forecast.
# - `id`: a unique identifier for the forecast.
# - `membership_guid`: a unique identifier for the forecaster.
# - `predictions`:  The IFP has 5 answers and the forecast includes probabilistic forecasts for all of the answers (multinomial or ordinal IFPs) or for the "Yes" answer (binary IFPs), found in the `forecasted_probability` field.  These forecasts add up to 1.0 (values are 0, 0, 0.5, 0.5, 0) for multinomial or ordinal IFPs.  For binary IFPs the forecast will be between 0 and 1.0 inclusive and the implicit forecast for the "No" answer is 1 - the forecast.
# - `question_id`: A unique identifier for the IFP.
# - `question_name`: The name of the IFP.
# - `rationale`: Forecaster entered text, explaining the reasoning behind the forecast.
# - `updated_at`: The timestamp the forecast was updated, generally the same as the `created_at` timestamp.

# %% [markdown]
# ```
# {'created_at': '2019-03-12T18:00:03.675Z',
#  'id': 64797,
#  'membership_guid': '4662cf7dbb06d39017571d84ea88d6f1d69100a8',
#  'predictions': [{'answer_id': 8161,
#                   'answer_name': 'Less than $1,240',
#                   'final_probability': 0.0,
#                   'forecasted_probability': 0.0,
#                   'id': 154343,
#                   'made_after_correctness_known': False,
#                   'starting_probability': 0.0},
#                  {'answer_id': 8162,
#                   'answer_name': 'More than $1,240 but less than $1,290, '
#                                  'inclusive',
#                   'final_probability': 0.2,
#                   'forecasted_probability': 0.5,
#                   'id': 154344,
#                   'made_after_correctness_known': False,
#                   'starting_probability': 0.2},
#                  {'answer_id': 8163,
#                   'answer_name': 'Between $1,290 and $1,330',
#                   'final_probability': 0.55,
#                   'forecasted_probability': 0.5,
#                   'id': 154345,
#                   'made_after_correctness_known': False,
#                   'starting_probability': 0.55},
#                  {'answer_id': 8164,
#                   'answer_name': 'More than $1,330 but less than $1,380, '
#                                  'inclusive',
#                   'final_probability': 0.1,
#                   'forecasted_probability': 0.0,
#                   'id': 154346,
#                   'made_after_correctness_known': False,
#                   'starting_probability': 0.1},
#                  {'answer_id': 8165,
#                   'answer_name': 'More than $1,380',
#                   'final_probability': 0.0,
#                   'forecasted_probability': 0.0,
#                   'id': 154347,
#                   'made_after_correctness_known': False,
#                   'starting_probability': 0.0}],
#  'question_id': 2995,
#  'question_name': 'What will be the daily closing price of gold on 13 March '
#                   '2019 in USD?',
#  'rationale': 'This is really down to the last minute. The price has been '
#               'teetering just around the 1290 mark for several days. It will '
#               'either be slightly above or slightly below 1290 by tomorrow, '
#               'which is the end of the time period.',
#  'updated_at': '2019-03-12T18:00:03.675Z'}
#  ```

# %% [markdown]
# We can retrieve the baseline consensus forecasts using `get_consensus_histories()`. As described in the API documentation, and above, after your first call to this API endpoint, you should constrain your requests using something like `created_after` while storing and tracking older values locally. Note that we're using `datetime.datetime()` objects to specify the `created` and `updated` parameters. You can limit this request by `question_id` if desired.

# %%
cons = gf.get_consensus_histories(created_after=datetime.datetime(2019,5,15,12,0,0),
                                  updated_before=datetime.datetime(2019,5,16),
                                  training_data=False) 
print("retrieved {} consensus scores".format(len(cons)))

# %% [markdown]
# Let's look at these results. Note that each item in the list represents a single answer -- unlike an item in the `get_human_forecasts()` results where each entry represents the predictions for each possible answer for a single IFP.
#
# The `normalized_value` scores for all the answers to a single IFP for a specific `consensus_at` time will add up to 1.0.

# %% [markdown]
# Here's an example consensus history from the training data on the staging platform.
#
# - `answer_id`: Identifier for the answer, matches the questions API.
# - `consensus_at`, `created_at`, `updated_at`: Timestamp for the consensus creation, computation, and update.  Typically the same or very close in time.
# - `decay_args`, `decay_method`, `strategy`, `weighting_settings`, `method_name`: "Under the hood" parameters for the method of aggregating individual forecasts to produce the consensus.  Solvers can ignore these.
# - `id`: The identifier for this consensus history.
# - `normalized_value`: **The baseline method forecast**, The consensus forecast value for this answer.
# - `prediction_set_id`:  Collective identifier for the answer consensus elements corresponding to the consensus for an IFP.
# - `question_id`: The identifier for the IFP
# - `value`: The raw output from the aggregator, **not to be used as a probability value**

# %% [markdown]
# ```
# {'answer_id': 7015,
#  'consensus_at': '2019-03-13T14:28:40.843Z',
#  'created_at': '2019-03-13T14:28:41.951Z',
#  'decay_args': {'percent': 0.468},
#  'decay_method': 'Aggregation::Decay::PercentRecent',
#  'id': 107249,
#  'method_name': '1-WeightedLogit-PercentRecent',
#  'normalized_value': 0.00166729,
#  'prediction_set_id': 64780,
#  'question_id': 2595,
#  'strategy': 'Aggregation::Strategies::Logit',
#  'updated_at': '2019-03-13T14:28:41.951Z',
#  'value': 0.013881,
#  'weighting_settings': {'count_of_closed_questions_answered_requirement': 35,
#                         'enabled': True,
#                         'minimum_closed_questions_to_enable_accuracy_weighting': 10,
#                         'percentage_of_closed_questions_answered_requirement': 0.5}}
# ```
